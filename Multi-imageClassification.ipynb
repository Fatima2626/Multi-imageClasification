# %% [markdown]
# # Computer Vision Project
#
# For our Computer Vision (CV) project, we utilized an image dataset obtained from [Kaggle](https://www.kaggle.com/datasets/pavansanagapati/images-dataset/data). The dataset includes:
#
# - Cats: 200 images
# - Dogs: 100 images
# - Horses: 150 images
#
# This dataset serves as the foundation for our multi-class image classification task, where we aim to design a comprehensive pipeline using Python along with libraries like NumPy, OpenCV, TensorFlow, etc. The pipeline covers data preparation, feature extraction using both low-level and high-level techniques, dimensionality reduction, and classification using Support Vector Machines (SVM) to achieve accurate classification results.

# %% [markdown]
# # Data Preparation with OpenCV and NumPy

# %% [markdown]
# # 1) Data Augmentation
#
# We balanced the distribution of images across classes by augmenting the dataset, ensuring each category has sufficient data for training. Using OpenCV, we implemented image augmentation techniques like rotation and flipping to create diverse variations of images, addressing class imbalances effectively. Additionally, we applied common image preprocessing techniques such as normalization, histogram equalization, and denoising to enhance image quality before feature extraction. These strategies collectively improved the dataset's quality and balance, making it suitable for computer vision tasks like classification or object detection.

# %%
import os
import cv2
import numpy as np
from random import choice

data_folder = 'C:/Users/irsha/Downloads/CV/data/'
folders = ['cats', 'dogs', 'horses']
target_count = 200

# performing image augmentation
def augment_images(image_folder, target_count):
    images = os.listdir(image_folder)
    num_images = len(images)
    if num_images >= target_count:
        return  
    num_augmentations = target_count - num_images
    for i in range(num_augmentations):
        image_name = choice(images)
        image_path = os.path.join(image_folder, image_name)
        image = cv2.imread(image_path)
        
        if image is not None:
    
            angle = np.random.randint(-15, 15)
            (h, w) = image.shape[:2]
            center = (w // 2, h // 2)
            M = cv2.getRotationMatrix2D(center, angle, 1.0) #rotation of the images
            rotated_image = cv2.warpAffine(image, M, (w, h))
            
            flip_code = choice([-1, 0, 1])
            flipped_image = cv2.flip(rotated_image, flip_code) #flipping of the images
            
            scale_factor = np.random.uniform(0.9, 1.1)
            scaled_image = cv2.resize(flipped_image, None, fx=scale_factor, fy=scale_factor) #random scaling of pictures

            scaled_image = cv2.resize(scaled_image, (w, h)) #resizing the images to original size

            cv2.imwrite(os.path.join(image_folder, f'augmented_{i}.jpg'), scaled_image)
            images.append(f'augmented_{i}.jpg')

def preprocess_image(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    normalized_image = cv2.normalize(gray_image, None, 0, 255, cv2.NORM_MINMAX)
    equalized_image = cv2.equalizeHist(normalized_image)
    denoised_image = cv2.fastNlMeansDenoising(equalized_image, h=10)
    return denoised_image

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    augment_images(folder_path, target_count)
    print(f'Image augmentation complete for "{folder}". Total images: {len(os.listdir(folder_path))}')

    # loop to preprocess all images
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        image = cv2.imread(img_path)
        if image is not None:
            preprocessed_image = preprocess_image(image)
            cv2.imwrite(img_path, preprocessed_image)
    print(f'Image preprocessing complete for "{folder}".')

print('Data preparation process complete for all folders.')
# Out:
# Image augmentation complete for "cats". Total images: 200
# Image preprocessing complete for "cats".
# Image augmentation complete for "dogs". Total images: 200
# Image preprocessing complete for "dogs".
# Image augmentation complete for "horses". Total images: 200
# Image preprocessing complete for "horses".
# Data preparation process complete for all folders.

# %% [markdown]
# # 2) Feature Extraction with OpenCV and TensorFlow

# %% [markdown]
# Low-level features are extracted using Histogram of Oriented Gradients (HOG) and Local Binary Patterns (LBP), while high-level features are obtained using a pre-trained deep Convolutional Neural Network (CNN). These features are then combined and subjected to dimensionality reduction before training a Support Vector Machine (SVM) classifier.
#  HOG captures edge and gradient structure information by computing gradients in localized portions of an image. This makes it highly effective for object detection and recognition tasks where shape and texture are crucial.
#   LBP is a texture descriptor that characterizes the local texture of an image by thresholding the neighborhood of each pixel and converting the result into a binary number. It is particularly useful for texture classification.

# %%
import os
import cv2
import numpy as np
from skimage.feature import local_binary_pattern

data_folder = 'C:/Users/irsha/Downloads/CV/data/'
folders = ['cats', 'dogs', 'horses']

def compute_hog_features(image):
    win_size = (64, 64)
    block_size = (16, 16)
    block_stride = (8, 8)
    cell_size = (8, 8)
    nbins = 9

    hog = cv2.HOGDescriptor(win_size, block_size, block_stride, cell_size, nbins)
    h = hog.compute(image)
    return h

def compute_lbp_features(image):
    radius = 3
    n_points = 8 * radius #number of sampling points
    lbp = local_binary_pattern(image, n_points, radius, method='uniform')
    (hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    return hist

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        
        if image is not None:
            hog_features = compute_hog_features(image)
            lbp_features = compute_lbp_features(image)
            
            print(f'HOG features shape for {img_name}: {hog_features.shape}')
            print(f'LBP features shape for {img_name}: {lbp_features.shape}')
# Out:
# HOG features shape for cat.1.jpg: (1481760,)
# LBP features shape for cat.1.jpg: (26,)
# HOG features shape for cat.10.jpg: (5239080,)
# LBP features shape for cat.10.jpg: (26,)
# HOG features shape for cat.100.jpg: (4171860,)
# LBP features shape for cat.100.jpg: (26,)
# HOG features shape for cat.101.jpg: (952560,)
# LBP features shape for cat.101.jpg: (26,)
# HOG features shape for cat.102.jpg: (2222640,)
# LBP features shape for cat.102.jpg: (26,)
# HOG features shape for cat.103.jpg: (3977820,)
# LBP features shape for cat.103.jpg: (26,)
# HOG features shape for cat.104.jpg: (1778112,)
# LBP features shape for cat.104.jpg: (26,)
# HOG features shape for cat.105.jpg: (469224,)
# LBP features shape for cat.105.jpg: (26,)
# HOG features shape for cat.106.jpg: (2958228,)
# LBP features shape for cat.106.jpg: (26,)
# HOG features shape for cat.107.jpg: (3492720,)
# LBP features shape for cat.107.jpg: (26,)
# HOG features shape for cat.108.jpg: (3298680,)
# LBP features shape for cat.108.jpg: (26,)
# HOG features shape for cat.109.jpg: (3783780,)
# LBP features shape for cat.109.jpg: (26,)
# HOG features shape for cat.11.jpg: (3570336,)
# LBP features shape for cat.11.jpg: (26,)
# HOG features shape for cat.110.jpg: (3783780,)
# LBP features shape for cat.110.jpg: (26,)
# HOG features shape for cat.111.jpg: (1958040,)
# LBP features shape for cat.111.jpg: (26,)
# HOG features shape for cat.112.jpg: (3783780,)
# LBP features shape for cat.112.jpg: (26,)
# HOG features shape for cat.113.jpg: (2406096,)
# LBP features shape for cat.113.jpg: (26,)
# HOG features shape for cat.114.jpg: (1587600,)
# LBP features shape for cat.114.jpg: (26,)
# HOG features shape for cat.115.jpg: (963144,)
# LBP features shape for cat.115.jpg: (26,)
# HOG features shape for cat.116.jpg: (3783780,)
# LBP features shape for cat.116.jpg: (26,)
# HOG features shape for cat.117.jpg: (2675988,)
# LBP features shape for cat.117.jpg: (26,)
# HOG features shape for cat.118.jpg: (3783780,)
# LBP features shape for cat.118.jpg: (26,)
# HOG features shape for cat.119.jpg: (2406096,)
# LBP features shape for cat.119.jpg: (26,)
# HOG features shape for cat.12.jpg: (1111320,)
# LBP features shape for cat.12.jpg: (26,)
# HOG features shape for cat.120.jpg: (3783780,)
# LBP features shape for cat.120.jpg: (26,)
# HOG features shape for cat.121.jpg: (2018016,)
# LBP features shape for cat.121.jpg: (26,)
# HOG features shape for cat.122.jpg: (3783780,)
# LBP features shape for cat.122.jpg: (26,)
# HOG features shape for cat.123.jpg: (1714608,)
# LBP features shape for cat.123.jpg: (26,)
# HOG features shape for cat.124.jpg: (3783780,)
# LBP features shape for cat.124.jpg: (26,)
# HOG features shape for cat.125.jpg: (5142060,)
# LBP features shape for cat.125.jpg: (26,)
# HOG features shape for cat.126.jpg: (2351412,)
# LBP features shape for cat.126.jpg: (26,)
# HOG features shape for cat.127.jpg: (1742832,)
# LBP features shape for cat.127.jpg: (26,)
# HOG features shape for cat.128.jpg: (3783780,)
# LBP features shape for cat.128.jpg: (26,)
# HOG features shape for cat.129.jpg: (3395700,)
# LBP features shape for cat.129.jpg: (26,)
# HOG features shape for cat.13.jpg: (3104640,)
# LBP features shape for cat.13.jpg: (26,)
# HOG features shape for cat.130.jpg: (4365900,)
# LBP features shape for cat.130.jpg: (26,)
# HOG features shape for cat.131.jpg: (3783780,)
# LBP features shape for cat.131.jpg: (26,)
# HOG features shape for cat.132.jpg: (3395700,)
# LBP features shape for cat.132.jpg: (26,)
# HOG features shape for cat.133.jpg: (3783780,)
# LBP features shape for cat.133.jpg: (26,)
# HOG features shape for cat.134.jpg: (3783780,)
# LBP features shape for cat.134.jpg: (26,)
# HOG features shape for cat.135.jpg: (4674600,)
# LBP features shape for cat.135.jpg: (26,)
# HOG features shape for cat.136.jpg: (3783780,)
# LBP features shape for cat.136.jpg: (26,)
# HOG features shape for cat.137.jpg: (3977820,)
# LBP features shape for cat.137.jpg: (26,)
# HOG features shape for cat.138.jpg: (1571724,)
# LBP features shape for cat.138.jpg: (26,)
# HOG features shape for cat.139.jpg: (2910600,)
# LBP features shape for cat.139.jpg: (26,)
# HOG features shape for cat.14.jpg: (1513512,)
# LBP features shape for cat.14.jpg: (26,)
# HOG features shape for cat.140.jpg: (1100736,)
# LBP features shape for cat.140.jpg: (26,)
# HOG features shape for cat.141.jpg: (3783780,)
# LBP features shape for cat.141.jpg: (26,)
# HOG features shape for cat.142.jpg: (3783780,)
# LBP features shape for cat.142.jpg: (26,)
# HOG features shape for cat.143.jpg: (3783780,)
# LBP features shape for cat.143.jpg: (26,)
# HOG features shape for cat.144.jpg: (3783780,)
# LBP features shape for cat.144.jpg: (26,)
# HOG features shape for cat.145.jpg: (3027024,)
# LBP features shape for cat.145.jpg: (26,)
# HOG features shape for cat.146.jpg: (37044,)
# LBP features shape for cat.146.jpg: (26,)
# HOG features shape for cat.147.jpg: (2275560,)
# LBP features shape for cat.147.jpg: (26,)
# HOG features shape for cat.148.jpg: (1280664,)
# LBP features shape for cat.148.jpg: (26,)
# HOG features shape for cat.149.jpg: (4948020,)
# LBP features shape for cat.149.jpg: (26,)
# HOG features shape for cat.15.jpg: (2806524,)
# LBP features shape for cat.15.jpg: (26,)
# HOG features shape for cat.150.jpg: (3783780,)
# LBP features shape for cat.150.jpg: (26,)
# HOG features shape for cat.151.jpg: (3783780,)
# LBP features shape for cat.151.jpg: (26,)
# HOG features shape for cat.152.jpg: (3589740,)
# LBP features shape for cat.152.jpg: (26,)
# HOG features shape for cat.153.jpg: (2328480,)
# LBP features shape for cat.153.jpg: (26,)
# HOG features shape for cat.154.jpg: (613872,)
# LBP features shape for cat.154.jpg: (26,)
# HOG features shape for cat.155.jpg: (2716560,)
# LBP features shape for cat.155.jpg: (26,)
# HOG features shape for cat.156.jpg: (3783780,)
# LBP features shape for cat.156.jpg: (26,)
# HOG features shape for cat.157.jpg: (1016064,)
# LBP features shape for cat.157.jpg: (26,)
# HOG features shape for cat.158.jpg: (5045040,)
# LBP features shape for cat.158.jpg: (26,)
# HOG features shape for cat.159.jpg: (4656960,)
# LBP features shape for cat.159.jpg: (26,)
# HOG features shape for cat.16.jpg: (2160900,)
# LBP features shape for cat.16.jpg: (26,)
# HOG features shape for cat.160.jpg: (3783780,)
# LBP features shape for cat.160.jpg: (26,)
# HOG features shape for cat.161.jpg: (4851000,)
# LBP features shape for cat.161.jpg: (26,)
# HOG features shape for cat.162.jpg: (2593080,)
# LBP features shape for cat.162.jpg: (26,)
# HOG features shape for cat.163.jpg: (3783780,)
# LBP features shape for cat.163.jpg: (26,)
# HOG features shape for cat.164.jpg: (3783780,)
# LBP features shape for cat.164.jpg: (26,)
# HOG features shape for cat.165.jpg: (1333584,)
# LBP features shape for cat.165.jpg: (26,)
# HOG features shape for cat.166.jpg: (2503116,)
# LBP features shape for cat.166.jpg: (26,)
# HOG features shape for cat.167.jpg: (4365900,)
# LBP features shape for cat.167.jpg: (26,)
# HOG features shape for cat.168.jpg: (1016064,)
# LBP features shape for cat.168.jpg: (26,)
# HOG features shape for cat.169.jpg: (3783780,)
# LBP features shape for cat.169.jpg: (26,)
# HOG features shape for cat.17.jpg: (3783780,)
# LBP features shape for cat.17.jpg: (26,)
# HOG features shape for cat.170.jpg: (3201660,)
# LBP features shape for cat.170.jpg: (26,)
# HOG features shape for cat.171.jpg: (1580544,)
# LBP features shape for cat.171.jpg: (26,)
# HOG features shape for cat.172.jpg: (465696,)
# LBP features shape for cat.172.jpg: (26,)
# HOG features shape for cat.173.jpg: (5239080,)
# LBP features shape for cat.173.jpg: (26,)
# HOG features shape for cat.174.jpg: (4462920,)
# LBP features shape for cat.174.jpg: (26,)
# HOG features shape for cat.175.jpg: (1111320,)
# LBP features shape for cat.175.jpg: (26,)
# HOG features shape for cat.176.jpg: (2145024,)
# LBP features shape for cat.176.jpg: (26,)
# HOG features shape for cat.177.jpg: (3492720,)
# LBP features shape for cat.177.jpg: (26,)
# HOG features shape for cat.178.jpg: (3175200,)
# LBP features shape for cat.178.jpg: (26,)
# HOG features shape for cat.179.jpg: (3880800,)
# LBP features shape for cat.179.jpg: (26,)
# HOG features shape for cat.18.jpg: (3783780,)
# LBP features shape for cat.18.jpg: (26,)
# HOG features shape for cat.180.jpg: (3492720,)
# LBP features shape for cat.180.jpg: (26,)
# HOG features shape for cat.181.jpg: (952560,)
# LBP features shape for cat.181.jpg: (26,)
# HOG features shape for cat.182.jpg: (3783780,)
# LBP features shape for cat.182.jpg: (26,)
# HOG features shape for cat.183.jpg: (42336,)
# LBP features shape for cat.183.jpg: (26,)
# HOG features shape for cat.184.jpg: (5045040,)
# LBP features shape for cat.184.jpg: (26,)
# HOG features shape for cat.185.jpg: (4559940,)
# LBP features shape for cat.185.jpg: (26,)
# HOG features shape for cat.186.jpg: (1111320,)
# LBP features shape for cat.186.jpg: (26,)
# HOG features shape for cat.187.jpg: (3783780,)
# LBP features shape for cat.187.jpg: (26,)
# HOG features shape for cat.188.jpg: (1555848,)
# LBP features shape for cat.188.jpg: (26,)
# HOG features shape for cat.189.jpg: (4948020,)
# LBP features shape for cat.189.jpg: (26,)
# HOG features shape for cat.19.jpg: (1164240,)
# LBP features shape for cat.19.jpg: (26,)
# HOG features shape for cat.190.jpg: (3686760,)
# LBP features shape for cat.190.jpg: (26,)
# HOG features shape for cat.191.jpg: (3880800,)
# LBP features shape for cat.191.jpg: (26,)
# HOG features shape for cat.192.jpg: (3783780,)
# LBP features shape for cat.192.jpg: (26,)
# HOG features shape for cat.193.jpg: (449820,)
# LBP features shape for cat.193.jpg: (26,)
# HOG features shape for cat.194.jpg: (5336100,)
# LBP features shape for cat.194.jpg: (26,)
# HOG features shape for cat.195.jpg: (3783780,)
# LBP features shape for cat.195.jpg: (26,)
# HOG features shape for cat.196.jpg: (2667168,)
# LBP features shape for cat.196.jpg: (26,)
# HOG features shape for cat.197.jpg: (2716560,)
# LBP features shape for cat.197.jpg: (26,)
# HOG features shape for cat.198.jpg: (3783780,)
# LBP features shape for cat.198.jpg: (26,)
# HOG features shape for cat.199.jpg: (1467648,)
# LBP features shape for cat.199.jpg: (26,)
# HOG features shape for cat.2.jpg: (2370816,)
# LBP features shape for cat.2.jpg: (26,)
# HOG features shape for cat.20.jpg: (3783780,)
# LBP features shape for cat.20.jpg: (26,)
# HOG features shape for cat.200.jpg: (3783780,)
# LBP features shape for cat.200.jpg: (26,)
# HOG features shape for cat.21.jpg: (4462920,)
# LBP features shape for cat.21.jpg: (26,)
# HOG features shape for cat.22.jpg: (3492720,)
# LBP features shape for cat.22.jpg: (26,)
# HOG features shape for cat.23.jpg: (1499400,)
# LBP features shape for cat.23.jpg: (26,)
# HOG features shape for cat.24.jpg: (3783780,)
# LBP features shape for cat.24.jpg: (26,)
# HOG features shape for cat.25.jpg: (3492720,)
# LBP features shape for cat.25.jpg: (26,)
# HOG features shape for cat.26.jpg: (3783780,)
# LBP features shape for cat.26.jpg: (26,)
# HOG features shape for cat.27.jpg: (3577392,)
# LBP features shape for cat.27.jpg: (26,)
# HOG features shape for cat.28.jpg: (1284192,)
# LBP features shape for cat.28.jpg: (26,)
# HOG features shape for cat.29.jpg: (3783780,)
# LBP features shape for cat.29.jpg: (26,)
# HOG features shape for cat.3.jpg: (4268880,)
# LBP features shape for cat.3.jpg: (26,)
# HOG features shape for cat.30.jpg: (1587600,)
# LBP features shape for cat.30.jpg: (26,)
# HOG features shape for cat.31.jpg: (3783780,)
# LBP features shape for cat.31.jpg: (26,)
# HOG features shape for cat.32.jpg: (3783780,)
# LBP features shape for cat.32.jpg: (26,)
# HOG features shape for cat.33.jpg: (3783780,)
# LBP features shape for cat.33.jpg: (26,)
# HOG features shape for cat.34.jpg: (3783780,)
# LBP features shape for cat.34.jpg: (26,)
# HOG features shape for cat.35.jpg: (4462920,)
# LBP features shape for cat.35.jpg: (26,)
# HOG features shape for cat.36.jpg: (3007620,)
# LBP features shape for cat.36.jpg: (26,)
# HOG features shape for cat.37.jpg: (3395700,)
# LBP features shape for cat.37.jpg: (26,)
# HOG features shape for cat.38.jpg: (2222640,)
# LBP features shape for cat.38.jpg: (26,)
# HOG features shape for cat.39.jpg: (3783780,)
# LBP features shape for cat.39.jpg: (26,)
# HOG features shape for cat.4.jpg: (3783780,)
# LBP features shape for cat.4.jpg: (26,)
# HOG features shape for cat.40.jpg: (3880800,)
# LBP features shape for cat.40.jpg: (26,)
# HOG features shape for cat.41.jpg: (3298680,)
# LBP features shape for cat.41.jpg: (26,)
# HOG features shape for cat.42.jpg: (543312,)
# LBP features shape for cat.42.jpg: (26,)
# HOG features shape for cat.43.jpg: (3589740,)
# LBP features shape for cat.43.jpg: (26,)
# HOG features shape for cat.44.jpg: (52920,)
# LBP features shape for cat.44.jpg: (26,)
# HOG features shape for cat.45.jpg: (3783780,)
# LBP features shape for cat.45.jpg: (26,)
# HOG features shape for cat.46.jpg: (3565044,)
# LBP features shape for cat.46.jpg: (26,)
# HOG features shape for cat.47.jpg: (837900,)
# LBP features shape for cat.47.jpg: (26,)
# HOG features shape for cat.48.jpg: (70560,)
# LBP features shape for cat.48.jpg: (26,)
# HOG features shape for cat.49.jpg: (238140,)
# LBP features shape for cat.49.jpg: (26,)
# HOG features shape for cat.5.jpg: (271656,)
# LBP features shape for cat.5.jpg: (26,)
# HOG features shape for cat.50.jpg: (899640,)
# LBP features shape for cat.50.jpg: (26,)
# HOG features shape for cat.51.jpg: (2293200,)
# LBP features shape for cat.51.jpg: (26,)
# HOG features shape for cat.52.jpg: (2222640,)
# LBP features shape for cat.52.jpg: (26,)
# HOG features shape for cat.53.jpg: (4762800,)
# LBP features shape for cat.53.jpg: (26,)
# HOG features shape for cat.54.jpg: (5336100,)
# LBP features shape for cat.54.jpg: (26,)
# HOG features shape for cat.55.jpg: (3492720,)
# LBP features shape for cat.55.jpg: (26,)
# HOG features shape for cat.56.jpg: (3298680,)
# LBP features shape for cat.56.jpg: (26,)
# HOG features shape for cat.57.jpg: (1739304,)
# LBP features shape for cat.57.jpg: (26,)
# HOG features shape for cat.58.jpg: (3783780,)
# LBP features shape for cat.58.jpg: (26,)
# HOG features shape for cat.59.jpg: (3058776,)
# LBP features shape for cat.59.jpg: (26,)
# HOG features shape for cat.6.jpg: (2275560,)
# LBP features shape for cat.6.jpg: (26,)
# HOG features shape for cat.60.jpg: (396900,)
# LBP features shape for cat.60.jpg: (26,)
# HOG features shape for cat.61.jpg: (1259496,)
# LBP features shape for cat.61.jpg: (26,)
# HOG features shape for cat.62.jpg: (3880800,)
# LBP features shape for cat.62.jpg: (26,)
# HOG features shape for cat.63.jpg: (3783780,)
# LBP features shape for cat.63.jpg: (26,)
# HOG features shape for cat.64.jpg: (3783780,)
# LBP features shape for cat.64.jpg: (26,)
# HOG features shape for cat.65.jpg: (3783780,)
# LBP features shape for cat.65.jpg: (26,)
# HOG features shape for cat.66.jpg: (3880800,)
# LBP features shape for cat.66.jpg: (26,)
# HOG features shape for cat.67.jpg: (3783780,)
# LBP features shape for cat.67.jpg: (26,)
# HOG features shape for cat.68.jpg: (635040,)
# LBP features shape for cat.68.jpg: (26,)
# HOG features shape for cat.69.jpg: (3783780,)
# LBP features shape for cat.69.jpg: (26,)
# HOG features shape for cat.7.jpg: (5239080,)
# LBP features shape for cat.7.jpg: (26,)
# HOG features shape for cat.70.jpg: (3783780,)
# LBP features shape for cat.70.jpg: (26,)
# HOG features shape for cat.71.jpg: (4365900,)
# LBP features shape for cat.71.jpg: (26,)
# HOG features shape for cat.72.jpg: (3178728,)
# LBP features shape for cat.72.jpg: (26,)
# HOG features shape for cat.73.jpg: (3783780,)
# LBP features shape for cat.73.jpg: (26,)
# HOG features shape for cat.74.jpg: (508032,)
# LBP features shape for cat.74.jpg: (26,)
# HOG features shape for cat.75.jpg: (4000752,)
# LBP features shape for cat.75.jpg: (26,)
# HOG features shape for cat.76.jpg: (2425500,)
# LBP features shape for cat.76.jpg: (26,)
# HOG features shape for cat.77.jpg: (1397088,)
# LBP features shape for cat.77.jpg: (26,)
# HOG features shape for cat.78.jpg: (5336100,)
# LBP features shape for cat.78.jpg: (26,)
# HOG features shape for cat.79.jpg: (3492720,)
# LBP features shape for cat.79.jpg: (26,)
# HOG features shape for cat.8.jpg: (3175200,)
# LBP features shape for cat.8.jpg: (26,)
# HOG features shape for cat.80.jpg: (1241856,)
# LBP features shape for cat.80.jpg: (26,)
# HOG features shape for cat.81.jpg: (3783780,)
# LBP features shape for cat.81.jpg: (26,)
# HOG features shape for cat.82.jpg: (3298680,)
# LBP features shape for cat.82.jpg: (26,)
# HOG features shape for cat.83.jpg: (3783780,)
# LBP features shape for cat.83.jpg: (26,)
# HOG features shape for cat.84.jpg: (2272032,)
# LBP features shape for cat.84.jpg: (26,)
# HOG features shape for cat.85.jpg: (2963520,)
# LBP features shape for cat.85.jpg: (26,)
# HOG features shape for cat.86.jpg: (5239080,)
# LBP features shape for cat.86.jpg: (26,)
# HOG features shape for cat.87.jpg: (3783780,)
# LBP features shape for cat.87.jpg: (26,)
# HOG features shape for cat.88.jpg: (1926288,)
# LBP features shape for cat.88.jpg: (26,)
# HOG features shape for cat.89.jpg: (5239080,)
# LBP features shape for cat.89.jpg: (26,)
# HOG features shape for cat.9.jpg: (2677752,)
# LBP features shape for cat.9.jpg: (26,)
# HOG features shape for cat.90.jpg: (2963520,)
# LBP features shape for cat.90.jpg: (26,)
# HOG features shape for cat.91.jpg: (3783780,)
# LBP features shape for cat.91.jpg: (26,)
# HOG features shape for cat.92.jpg: (3783780,)
# LBP features shape for cat.92.jpg: (26,)
# HOG features shape for cat.93.jpg: (2286144,)
# LBP features shape for cat.93.jpg: (26,)
# HOG features shape for cat.94.jpg: (2286144,)
# LBP features shape for cat.94.jpg: (26,)
# HOG features shape for cat.95.jpg: (1241856,)
# LBP features shape for cat.95.jpg: (26,)
# HOG features shape for cat.96.jpg: (3783780,)
# LBP features shape for cat.96.jpg: (26,)
# HOG features shape for cat.97.jpg: (3783780,)
# LBP features shape for cat.97.jpg: (26,)
# HOG features shape for cat.98.jpg: (3669120,)
# LBP features shape for cat.98.jpg: (26,)
# HOG features shape for cat.99.jpg: (518616,)
# LBP features shape for cat.99.jpg: (26,)
# HOG features shape for augmented_0.jpg: (3783780,)
# LBP features shape for augmented_0.jpg: (26,)
# HOG features shape for augmented_1.jpg: (395136,)
# LBP features shape for augmented_1.jpg: (26,)
# HOG features shape for augmented_10.jpg: (3783780,)
# LBP features shape for augmented_10.jpg: (26,)
# HOG features shape for augmented_11.jpg: (5142060,)
# LBP features shape for augmented_11.jpg: (26,)
# HOG features shape for augmented_12.jpg: (1926288,)
# LBP features shape for augmented_12.jpg: (26,)
# HOG features shape for augmented_13.jpg: (1111320,)
# LBP features shape for augmented_13.jpg: (26,)
# HOG features shape for augmented_14.jpg: (3783780,)
# LBP features shape for augmented_14.jpg: (26,)
# HOG features shape for augmented_15.jpg: (1111320,)
# LBP features shape for augmented_15.jpg: (26,)
# HOG features shape for augmented_16.jpg: (2275560,)
# LBP features shape for augmented_16.jpg: (26,)
# HOG features shape for augmented_17.jpg: (1111320,)
# LBP features shape for augmented_17.jpg: (26,)
# HOG features shape for augmented_18.jpg: (599760,)
# LBP features shape for augmented_18.jpg: (26,)
# HOG features shape for augmented_19.jpg: (359856,)
# LBP features shape for augmented_19.jpg: (26,)
# HOG features shape for augmented_2.jpg: (2716560,)
# LBP features shape for augmented_2.jpg: (26,)
# HOG features shape for augmented_20.jpg: (3201660,)
# LBP features shape for augmented_20.jpg: (26,)
# HOG features shape for augmented_21.jpg: (3783780,)
# LBP features shape for augmented_21.jpg: (26,)
# HOG features shape for augmented_22.jpg: (3783780,)
# LBP features shape for augmented_22.jpg: (26,)
# HOG features shape for augmented_23.jpg: (3298680,)
# LBP features shape for augmented_23.jpg: (26,)
# HOG features shape for augmented_24.jpg: (359856,)
# LBP features shape for augmented_24.jpg: (26,)
# HOG features shape for augmented_25.jpg: (1111320,)
# LBP features shape for augmented_25.jpg: (26,)
# HOG features shape for augmented_26.jpg: (5239080,)
# LBP features shape for augmented_26.jpg: (26,)
# HOG features shape for augmented_27.jpg: (1270080,)
# LBP features shape for augmented_27.jpg: (26,)
# HOG features shape for augmented_28.jpg: (3298680,)
# LBP features shape for augmented_28.jpg: (26,)
# HOG features shape for augmented_29.jpg: (338688,)
# LBP features shape for augmented_29.jpg: (26,)
# HOG features shape for augmented_3.jpg: (338688,)
# LBP features shape for augmented_3.jpg: (26,)
# HOG features shape for augmented_30.jpg: (4074840,)
# LBP features shape for augmented_30.jpg: (26,)
# HOG features shape for augmented_31.jpg: (3783780,)
# LBP features shape for augmented_31.jpg: (26,)
# HOG features shape for augmented_32.jpg: (4074840,)
# LBP features shape for augmented_32.jpg: (26,)
# HOG features shape for augmented_33.jpg: (5239080,)
# LBP features shape for augmented_33.jpg: (26,)
# HOG features shape for augmented_34.jpg: (3783780,)
# LBP features shape for augmented_34.jpg: (26,)
# HOG features shape for augmented_35.jpg: (3025260,)
# LBP features shape for augmented_35.jpg: (26,)
# HOG features shape for augmented_36.jpg: (338688,)
# LBP features shape for augmented_36.jpg: (26,)
# HOG features shape for augmented_37.jpg: (1111320,)
# LBP features shape for augmented_37.jpg: (26,)
# HOG features shape for augmented_38.jpg: (3783780,)
# LBP features shape for augmented_38.jpg: (26,)
# HOG features shape for augmented_39.jpg: (4074840,)
# LBP features shape for augmented_39.jpg: (26,)
# HOG features shape for augmented_4.jpg: (4074840,)
# LBP features shape for augmented_4.jpg: (26,)
# HOG features shape for augmented_40.jpg: (63504,)
# LBP features shape for augmented_40.jpg: (26,)
# HOG features shape for augmented_41.jpg: (1111320,)
# LBP features shape for augmented_41.jpg: (26,)
# HOG features shape for augmented_42.jpg: (3298680,)
# LBP features shape for augmented_42.jpg: (26,)
# HOG features shape for augmented_43.jpg: (3025260,)
# LBP features shape for augmented_43.jpg: (26,)
# HOG features shape for augmented_44.jpg: (3201660,)
# LBP features shape for augmented_44.jpg: (26,)
# HOG features shape for augmented_45.jpg: (1111320,)
# LBP features shape for augmented_45.jpg: (26,)
# HOG features shape for augmented_46.jpg: (3783780,)
# LBP features shape for augmented_46.jpg: (26,)
# HOG features shape for augmented_47.jpg: (1111320,)
# LBP features shape for augmented_47.jpg: (26,)
# HOG features shape for augmented_48.jpg: (2679516,)
# LBP features shape for augmented_48.jpg: (26,)
# HOG features shape for augmented_49.jpg: (1270080,)
# LBP features shape for augmented_49.jpg: (26,)
# HOG features shape for augmented_5.jpg: (1241856,)
# LBP features shape for augmented_5.jpg: (26,)
# HOG features shape for augmented_50.jpg: (4074840,)
# LBP features shape for augmented_50.jpg: (26,)
# HOG features shape for augmented_51.jpg: (4948020,)
# LBP features shape for augmented_51.jpg: (26,)
# HOG features shape for augmented_52.jpg: (3783780,)
# LBP features shape for augmented_52.jpg: (26,)
# HOG features shape for augmented_53.jpg: (3783780,)
# LBP features shape for augmented_53.jpg: (26,)
# HOG features shape for augmented_54.jpg: (3783780,)
# LBP features shape for augmented_54.jpg: (26,)
# HOG features shape for augmented_55.jpg: (3977820,)
# LBP features shape for augmented_55.jpg: (26,)
# HOG features shape for augmented_56.jpg: (1111320,)
# LBP features shape for augmented_56.jpg: (26,)
# HOG features shape for augmented_57.jpg: (2716560,)
# LBP features shape for augmented_57.jpg: (26,)
# HOG features shape for augmented_58.jpg: (1298304,)
# LBP features shape for augmented_58.jpg: (26,)
# HOG features shape for augmented_59.jpg: (3783780,)
# LBP features shape for augmented_59.jpg: (26,)
# HOG features shape for augmented_6.jpg: (3783780,)
# LBP features shape for augmented_6.jpg: (26,)
# HOG features shape for augmented_60.jpg: (3880800,)
# LBP features shape for augmented_60.jpg: (26,)
# HOG features shape for augmented_61.jpg: (3201660,)
# LBP features shape for augmented_61.jpg: (26,)
# HOG features shape for augmented_62.jpg: (4171860,)
# LBP features shape for augmented_62.jpg: (26,)
# HOG features shape for augmented_63.jpg: (395136,)
# LBP features shape for augmented_63.jpg: (26,)
# HOG features shape for augmented_64.jpg: (2679516,)
# LBP features shape for augmented_64.jpg: (26,)
# HOG features shape for augmented_65.jpg: (3025260,)
# LBP features shape for augmented_65.jpg: (26,)
# HOG features shape for augmented_66.jpg: (1619352,)
# LBP features shape for augmented_66.jpg: (26,)
# HOG features shape for augmented_67.jpg: (3783780,)
# LBP features shape for augmented_67.jpg: (26,)
# HOG features shape for augmented_68.jpg: (3783780,)
# LBP features shape for augmented_68.jpg: (26,)
# HOG features shape for augmented_69.jpg: (3395700,)
# LBP features shape for augmented_69.jpg: (26,)
# HOG features shape for augmented_7.jpg: (3783780,)
# LBP features shape for augmented_7.jpg: (26,)
# HOG features shape for augmented_70.jpg: (3201660,)
# LBP features shape for augmented_70.jpg: (26,)
# HOG features shape for augmented_71.jpg: (395136,)
# LBP features shape for augmented_71.jpg: (26,)
# HOG features shape for augmented_72.jpg: (1111320,)
# LBP features shape for augmented_72.jpg: (26,)
# HOG features shape for augmented_73.jpg: (4074840,)
# LBP features shape for augmented_73.jpg: (26,)
# HOG features shape for augmented_74.jpg: (3686760,)
# LBP features shape for augmented_74.jpg: (26,)
# HOG features shape for augmented_75.jpg: (1241856,)
# LBP features shape for augmented_75.jpg: (26,)
# HOG features shape for augmented_76.jpg: (3783780,)
# LBP features shape for augmented_76.jpg: (26,)
# HOG features shape for augmented_77.jpg: (5142060,)
# LBP features shape for augmented_77.jpg: (26,)
# HOG features shape for augmented_78.jpg: (4171860,)
# LBP features shape for augmented_78.jpg: (26,)
# HOG features shape for augmented_79.jpg: (4074840,)
# LBP features shape for augmented_79.jpg: (26,)
# HOG features shape for augmented_8.jpg: (3395700,)
# LBP features shape for augmented_8.jpg: (26,)
# HOG features shape for augmented_80.jpg: (3783780,)
# LBP features shape for augmented_80.jpg: (26,)
# HOG features shape for augmented_81.jpg: (3783780,)
# LBP features shape for augmented_81.jpg: (26,)
# HOG features shape for augmented_82.jpg: (3783780,)
# LBP features shape for augmented_82.jpg: (26,)
# HOG features shape for augmented_83.jpg: (1111320,)
# LBP features shape for augmented_83.jpg: (26,)
# HOG features shape for augmented_84.jpg: (359856,)
# LBP features shape for augmented_84.jpg: (26,)
# HOG features shape for augmented_85.jpg: (3201660,)
# LBP features shape for augmented_85.jpg: (26,)
# HOG features shape for augmented_86.jpg: (3298680,)
# LBP features shape for augmented_86.jpg: (26,)
# HOG features shape for augmented_87.jpg: (3783780,)
# LBP features shape for augmented_87.jpg: (26,)
# HOG features shape for augmented_88.jpg: (3783780,)
# LBP features shape for augmented_88.jpg: (26,)
# HOG features shape for augmented_89.jpg: (1338876,)
# LBP features shape for augmented_89.jpg: (26,)
# HOG features shape for augmented_9.jpg: (3783780,)
# LBP features shape for augmented_9.jpg: (26,)
# HOG features shape for augmented_90.jpg: (5239080,)
# LBP features shape for augmented_90.jpg: (26,)
# HOG features shape for augmented_91.jpg: (4559940,)
# LBP features shape for augmented_91.jpg: (26,)
# HOG features shape for augmented_92.jpg: (3298680,)
# LBP features shape for augmented_92.jpg: (26,)
# HOG features shape for augmented_93.jpg: (3783780,)
# LBP features shape for augmented_93.jpg: (26,)
# HOG features shape for augmented_94.jpg: (599760,)
# LBP features shape for augmented_94.jpg: (26,)
# HOG features shape for augmented_95.jpg: (2677752,)
# LBP features shape for augmented_95.jpg: (26,)
# HOG features shape for augmented_96.jpg: (338688,)
# LBP features shape for augmented_96.jpg: (26,)
# HOG features shape for augmented_97.jpg: (3395700,)
# LBP features shape for augmented_97.jpg: (26,)
# HOG features shape for augmented_98.jpg: (1270080,)
# LBP features shape for augmented_98.jpg: (26,)
# HOG features shape for augmented_99.jpg: (3783780,)
# LBP features shape for augmented_99.jpg: (26,)
# HOG features shape for dog.1.jpg: (3201660,)
# LBP features shape for dog.1.jpg: (26,)
# HOG features shape for dog.10.jpg: (1330056,)
# LBP features shape for dog.10.jpg: (26,)
# HOG features shape for dog.100.jpg: (4074840,)
# LBP features shape for dog.100.jpg: (26,)
# HOG features shape for dog.11.jpg: (79380,)
# LBP features shape for dog.11.jpg: (26,)
# HOG features shape for dog.12.jpg: (114660,)
# LBP features shape for dog.12.jpg: (26,)
# HOG features shape for dog.13.jpg: (3083472,)
# LBP features shape for dog.13.jpg: (26,)
# HOG features shape for dog.14.jpg: (3977820,)
# LBP features shape for dog.14.jpg: (26,)
# HOG features shape for dog.15.jpg: (3783780,)
# LBP features shape for dog.15.jpg: (26,)
# HOG features shape for dog.16.jpg: (3880800,)
# LBP features shape for dog.16.jpg: (26,)
# HOG features shape for dog.17.jpg: (1619352,)
# LBP features shape for dog.17.jpg: (26,)
# HOG features shape for dog.18.jpg: (1206576,)
# LBP features shape for dog.18.jpg: (26,)
# HOG features shape for dog.19.jpg: (1111320,)
# LBP features shape for dog.19.jpg: (26,)
# HOG features shape for dog.2.jpg: (479808,)
# LBP features shape for dog.2.jpg: (26,)
# HOG features shape for dog.20.jpg: (3298680,)
# LBP features shape for dog.20.jpg: (26,)
# HOG features shape for dog.21.jpg: (4268880,)
# LBP features shape for dog.21.jpg: (26,)
# HOG features shape for dog.22.jpg: (3783780,)
# LBP features shape for dog.22.jpg: (26,)
# HOG features shape for dog.23.jpg: (4171860,)
# LBP features shape for dog.23.jpg: (26,)
# HOG features shape for dog.24.jpg: (2619540,)
# LBP features shape for dog.24.jpg: (26,)
# HOG features shape for dog.25.jpg: (3783780,)
# LBP features shape for dog.25.jpg: (26,)
# HOG features shape for dog.26.jpg: (1111320,)
# LBP features shape for dog.26.jpg: (26,)
# HOG features shape for dog.27.jpg: (3783780,)
# LBP features shape for dog.27.jpg: (26,)
# HOG features shape for dog.28.jpg: (2321424,)
# LBP features shape for dog.28.jpg: (26,)
# HOG features shape for dog.29.jpg: (3880800,)
# LBP features shape for dog.29.jpg: (26,)
# HOG features shape for dog.3.jpg: (3783780,)
# LBP features shape for dog.3.jpg: (26,)
# HOG features shape for dog.30.jpg: (4498200,)
# LBP features shape for dog.30.jpg: (26,)
# HOG features shape for dog.31.jpg: (2910600,)
# LBP features shape for dog.31.jpg: (26,)
# HOG features shape for dog.32.jpg: (3783780,)
# LBP features shape for dog.32.jpg: (26,)
# HOG features shape for dog.33.jpg: (3783780,)
# LBP features shape for dog.33.jpg: (26,)
# HOG features shape for dog.34.jpg: (3783780,)
# LBP features shape for dog.34.jpg: (26,)
# HOG features shape for dog.35.jpg: (1338876,)
# LBP features shape for dog.35.jpg: (26,)
# HOG features shape for dog.36.jpg: (1298304,)
# LBP features shape for dog.36.jpg: (26,)
# HOG features shape for dog.37.jpg: (2958228,)
# LBP features shape for dog.37.jpg: (26,)
# HOG features shape for dog.38.jpg: (3783780,)
# LBP features shape for dog.38.jpg: (26,)
# HOG features shape for dog.39.jpg: (2153844,)
# LBP features shape for dog.39.jpg: (26,)
# HOG features shape for dog.4.jpg: (1481760,)
# LBP features shape for dog.4.jpg: (26,)
# HOG features shape for dog.40.jpg: (329868,)
# LBP features shape for dog.40.jpg: (26,)
# HOG features shape for dog.41.jpg: (1298304,)
# LBP features shape for dog.41.jpg: (26,)
# HOG features shape for dog.42.jpg: (3783780,)
# LBP features shape for dog.42.jpg: (26,)
# HOG features shape for dog.43.jpg: (1651104,)
# LBP features shape for dog.43.jpg: (26,)
# HOG features shape for dog.44.jpg: (3783780,)
# LBP features shape for dog.44.jpg: (26,)
# HOG features shape for dog.45.jpg: (2677752,)
# LBP features shape for dog.45.jpg: (26,)
# HOG features shape for dog.46.jpg: (1217160,)
# LBP features shape for dog.46.jpg: (26,)
# HOG features shape for dog.47.jpg: (5045040,)
# LBP features shape for dog.47.jpg: (26,)
# HOG features shape for dog.48.jpg: (3552696,)
# LBP features shape for dog.48.jpg: (26,)
# HOG features shape for dog.49.jpg: (3783780,)
# LBP features shape for dog.49.jpg: (26,)
# HOG features shape for dog.5.jpg: (3880800,)
# LBP features shape for dog.5.jpg: (26,)
# HOG features shape for dog.50.jpg: (359856,)
# LBP features shape for dog.50.jpg: (26,)
# HOG features shape for dog.51.jpg: (4559940,)
# LBP features shape for dog.51.jpg: (26,)
# HOG features shape for dog.52.jpg: (3880800,)
# LBP features shape for dog.52.jpg: (26,)
# HOG features shape for dog.53.jpg: (1926288,)
# LBP features shape for dog.53.jpg: (26,)
# HOG features shape for dog.54.jpg: (2123856,)
# LBP features shape for dog.54.jpg: (26,)
# HOG features shape for dog.55.jpg: (4365900,)
# LBP features shape for dog.55.jpg: (26,)
# HOG features shape for dog.56.jpg: (5239080,)
# LBP features shape for dog.56.jpg: (26,)
# HOG features shape for dog.57.jpg: (2275560,)
# LBP features shape for dog.57.jpg: (26,)
# HOG features shape for dog.58.jpg: (2716560,)
# LBP features shape for dog.58.jpg: (26,)
# HOG features shape for dog.59.jpg: (3298680,)
# LBP features shape for dog.59.jpg: (26,)
# HOG features shape for dog.6.jpg: (5239080,)
# LBP features shape for dog.6.jpg: (26,)
# HOG features shape for dog.60.jpg: (2679516,)
# LBP features shape for dog.60.jpg: (26,)
# HOG features shape for dog.61.jpg: (3395700,)
# LBP features shape for dog.61.jpg: (26,)
# HOG features shape for dog.62.jpg: (3025260,)
# LBP features shape for dog.62.jpg: (26,)
# HOG features shape for dog.63.jpg: (4171860,)
# LBP features shape for dog.63.jpg: (26,)
# HOG features shape for dog.64.jpg: (4365900,)
# LBP features shape for dog.64.jpg: (26,)
# HOG features shape for dog.65.jpg: (338688,)
# LBP features shape for dog.65.jpg: (26,)
# HOG features shape for dog.66.jpg: (4074840,)
# LBP features shape for dog.66.jpg: (26,)
# HOG features shape for dog.67.jpg: (3185784,)
# LBP features shape for dog.67.jpg: (26,)
# HOG features shape for dog.68.jpg: (1270080,)
# LBP features shape for dog.68.jpg: (26,)
# HOG features shape for dog.69.jpg: (63504,)
# LBP features shape for dog.69.jpg: (26,)
# HOG features shape for dog.7.jpg: (1375920,)
# LBP features shape for dog.7.jpg: (26,)
# HOG features shape for dog.70.jpg: (1534680,)
# LBP features shape for dog.70.jpg: (26,)
# HOG features shape for dog.71.jpg: (3783780,)
# LBP features shape for dog.71.jpg: (26,)
# HOG features shape for dog.72.jpg: (3783780,)
# LBP features shape for dog.72.jpg: (26,)
# HOG features shape for dog.73.jpg: (1111320,)
# LBP features shape for dog.73.jpg: (26,)
# HOG features shape for dog.74.jpg: (3686760,)
# LBP features shape for dog.74.jpg: (26,)
# HOG features shape for dog.75.jpg: (3783780,)
# LBP features shape for dog.75.jpg: (26,)
# HOG features shape for dog.76.jpg: (395136,)
# LBP features shape for dog.76.jpg: (26,)
# HOG features shape for dog.77.jpg: (1913940,)
# LBP features shape for dog.77.jpg: (26,)
# HOG features shape for dog.78.jpg: (3783780,)
# LBP features shape for dog.78.jpg: (26,)
# HOG features shape for dog.79.jpg: (1016064,)
# LBP features shape for dog.79.jpg: (26,)
# HOG features shape for dog.8.jpg: (4948020,)
# LBP features shape for dog.8.jpg: (26,)
# HOG features shape for dog.80.jpg: (3439800,)
# LBP features shape for dog.80.jpg: (26,)
# HOG features shape for dog.81.jpg: (63504,)
# LBP features shape for dog.81.jpg: (26,)
# HOG features shape for dog.82.jpg: (4851000,)
# LBP features shape for dog.82.jpg: (26,)
# HOG features shape for dog.83.jpg: (3783780,)
# LBP features shape for dog.83.jpg: (26,)
# HOG features shape for dog.84.jpg: (3589740,)
# LBP features shape for dog.84.jpg: (26,)
# HOG features shape for dog.85.jpg: (852012,)
# LBP features shape for dog.85.jpg: (26,)
# HOG features shape for dog.86.jpg: (176400,)
# LBP features shape for dog.86.jpg: (26,)
# HOG features shape for dog.87.jpg: (3783780,)
# LBP features shape for dog.87.jpg: (26,)
# HOG features shape for dog.88.jpg: (3298680,)
# LBP features shape for dog.88.jpg: (26,)
# HOG features shape for dog.89.jpg: (3783780,)
# LBP features shape for dog.89.jpg: (26,)
# HOG features shape for dog.9.jpg: (3783780,)
# LBP features shape for dog.9.jpg: (26,)
# HOG features shape for dog.90.jpg: (2716560,)
# LBP features shape for dog.90.jpg: (26,)
# HOG features shape for dog.91.jpg: (599760,)
# LBP features shape for dog.91.jpg: (26,)
# HOG features shape for dog.92.jpg: (1241856,)
# LBP features shape for dog.92.jpg: (26,)
# HOG features shape for dog.93.jpg: (3783780,)
# LBP features shape for dog.93.jpg: (26,)
# HOG features shape for dog.94.jpg: (2381400,)
# LBP features shape for dog.94.jpg: (26,)
# HOG features shape for dog.95.jpg: (3298680,)
# LBP features shape for dog.95.jpg: (26,)
# HOG features shape for dog.96.jpg: (3783780,)
# LBP features shape for dog.96.jpg: (26,)
# HOG features shape for dog.97.jpg: (3783780,)
# LBP features shape for dog.97.jpg: (26,)
# HOG features shape for dog.98.jpg: (5142060,)
# LBP features shape for dog.98.jpg: (26,)
# HOG features shape for dog.99.jpg: (3783780,)
# LBP features shape for dog.99.jpg: (26,)
# HOG features shape for augmented_0.jpg: (714420,)
# LBP features shape for augmented_0.jpg: (26,)
# HOG features shape for augmented_1.jpg: (740880,)
# LBP features shape for augmented_1.jpg: (26,)
# HOG features shape for augmented_10.jpg: (714420,)
# LBP features shape for augmented_10.jpg: (26,)
# HOG features shape for augmented_11.jpg: (749700,)
# LBP features shape for augmented_11.jpg: (26,)
# HOG features shape for augmented_12.jpg: (3783780,)
# LBP features shape for augmented_12.jpg: (26,)
# HOG features shape for augmented_13.jpg: (749700,)
# LBP features shape for augmented_13.jpg: (26,)
# HOG features shape for augmented_14.jpg: (770868,)
# LBP features shape for augmented_14.jpg: (26,)
# HOG features shape for augmented_15.jpg: (749700,)
# LBP features shape for augmented_15.jpg: (26,)
# HOG features shape for augmented_16.jpg: (740880,)
# LBP features shape for augmented_16.jpg: (26,)
# HOG features shape for augmented_17.jpg: (740880,)
# LBP features shape for augmented_17.jpg: (26,)
# HOG features shape for augmented_18.jpg: (620928,)
# LBP features shape for augmented_18.jpg: (26,)
# HOG features shape for augmented_19.jpg: (749700,)
# LBP features shape for augmented_19.jpg: (26,)
# HOG features shape for augmented_2.jpg: (714420,)
# LBP features shape for augmented_2.jpg: (26,)
# HOG features shape for augmented_20.jpg: (740880,)
# LBP features shape for augmented_20.jpg: (26,)
# HOG features shape for augmented_21.jpg: (5397840,)
# LBP features shape for augmented_21.jpg: (26,)
# HOG features shape for augmented_22.jpg: (749700,)
# LBP features shape for augmented_22.jpg: (26,)
# HOG features shape for augmented_23.jpg: (719712,)
# LBP features shape for augmented_23.jpg: (26,)
# HOG features shape for augmented_24.jpg: (770868,)
# LBP features shape for augmented_24.jpg: (26,)
# HOG features shape for augmented_25.jpg: (749700,)
# LBP features shape for augmented_25.jpg: (26,)
# HOG features shape for augmented_26.jpg: (740880,)
# LBP features shape for augmented_26.jpg: (26,)
# HOG features shape for augmented_27.jpg: (4581108,)
# LBP features shape for augmented_27.jpg: (26,)
# HOG features shape for augmented_28.jpg: (762048,)
# LBP features shape for augmented_28.jpg: (26,)
# HOG features shape for augmented_29.jpg: (749700,)
# LBP features shape for augmented_29.jpg: (26,)
# HOG features shape for augmented_3.jpg: (733824,)
# LBP features shape for augmented_3.jpg: (26,)
# HOG features shape for augmented_30.jpg: (714420,)
# LBP features shape for augmented_30.jpg: (26,)
# HOG features shape for augmented_31.jpg: (749700,)
# LBP features shape for augmented_31.jpg: (26,)
# HOG features shape for augmented_32.jpg: (714420,)
# LBP features shape for augmented_32.jpg: (26,)
# HOG features shape for augmented_33.jpg: (359856,)
# LBP features shape for augmented_33.jpg: (26,)
# HOG features shape for augmented_34.jpg: (762048,)
# LBP features shape for augmented_34.jpg: (26,)
# HOG features shape for augmented_35.jpg: (749700,)
# LBP features shape for augmented_35.jpg: (26,)
# HOG features shape for augmented_36.jpg: (5397840,)
# LBP features shape for augmented_36.jpg: (26,)
# HOG features shape for augmented_37.jpg: (730296,)
# LBP features shape for augmented_37.jpg: (26,)
# HOG features shape for augmented_38.jpg: (48684636,)
# LBP features shape for augmented_38.jpg: (26,)
# HOG features shape for augmented_39.jpg: (740880,)
# LBP features shape for augmented_39.jpg: (26,)
# HOG features shape for augmented_4.jpg: (733824,)
# LBP features shape for augmented_4.jpg: (26,)
# HOG features shape for augmented_40.jpg: (749700,)
# LBP features shape for augmented_40.jpg: (26,)
# HOG features shape for augmented_41.jpg: (1319472,)
# LBP features shape for augmented_41.jpg: (26,)
# HOG features shape for augmented_42.jpg: (770868,)
# LBP features shape for augmented_42.jpg: (26,)
# HOG features shape for augmented_43.jpg: (777924,)
# LBP features shape for augmented_43.jpg: (26,)
# HOG features shape for augmented_44.jpg: (749700,)
# LBP features shape for augmented_44.jpg: (26,)
# HOG features shape for augmented_45.jpg: (749700,)
# LBP features shape for augmented_45.jpg: (26,)
# HOG features shape for augmented_46.jpg: (733824,)
# LBP features shape for augmented_46.jpg: (26,)
# HOG features shape for augmented_47.jpg: (749700,)
# LBP features shape for augmented_47.jpg: (26,)
# HOG features shape for augmented_48.jpg: (714420,)
# LBP features shape for augmented_48.jpg: (26,)
# HOG features shape for augmented_49.jpg: (527436,)
# LBP features shape for augmented_49.jpg: (26,)
# HOG features shape for augmented_5.jpg: (714420,)
# LBP features shape for augmented_5.jpg: (26,)
# HOG features shape for augmented_6.jpg: (749700,)
# LBP features shape for augmented_6.jpg: (26,)
# HOG features shape for augmented_7.jpg: (740880,)
# LBP features shape for augmented_7.jpg: (26,)
# HOG features shape for augmented_8.jpg: (762048,)
# LBP features shape for augmented_8.jpg: (26,)
# HOG features shape for augmented_9.jpg: (762048,)
# LBP features shape for augmented_9.jpg: (26,)
# HOG features shape for horse-1.jpg: (659736,)
# LBP features shape for horse-1.jpg: (26,)
# HOG features shape for horse-10.jpg: (5397840,)
# LBP features shape for horse-10.jpg: (26,)
# HOG features shape for horse-100.jpg: (730296,)
# LBP features shape for horse-100.jpg: (26,)
# HOG features shape for horse-101.jpg: (714420,)
# LBP features shape for horse-101.jpg: (26,)
# HOG features shape for horse-102.jpg: (719712,)
# LBP features shape for horse-102.jpg: (26,)
# HOG features shape for horse-103.jpg: (740880,)
# LBP features shape for horse-103.jpg: (26,)
# HOG features shape for horse-104.jpg: (749700,)
# LBP features shape for horse-104.jpg: (26,)
# HOG features shape for horse-105.jpg: (749700,)
# LBP features shape for horse-105.jpg: (26,)
# HOG features shape for horse-106.jpg: (740880,)
# LBP features shape for horse-106.jpg: (26,)
# HOG features shape for horse-107.jpg: (777924,)
# LBP features shape for horse-107.jpg: (26,)
# HOG features shape for horse-108.jpg: (749700,)
# LBP features shape for horse-108.jpg: (26,)
# HOG features shape for horse-109.jpg: (740880,)
# LBP features shape for horse-109.jpg: (26,)
# HOG features shape for horse-11.jpg: (714420,)
# LBP features shape for horse-11.jpg: (26,)
# HOG features shape for horse-110.jpg: (733824,)
# LBP features shape for horse-110.jpg: (26,)
# HOG features shape for horse-111.jpg: (620928,)
# LBP features shape for horse-111.jpg: (26,)
# HOG features shape for horse-112.jpg: (770868,)
# LBP features shape for horse-112.jpg: (26,)
# HOG features shape for horse-113.jpg: (714420,)
# LBP features shape for horse-113.jpg: (26,)
# HOG features shape for horse-114.jpg: (749700,)
# LBP features shape for horse-114.jpg: (26,)
# HOG features shape for horse-115.jpg: (733824,)
# LBP features shape for horse-115.jpg: (26,)
# HOG features shape for horse-116.jpg: (714420,)
# LBP features shape for horse-116.jpg: (26,)
# HOG features shape for horse-117.jpg: (714420,)
# LBP features shape for horse-117.jpg: (26,)
# HOG features shape for horse-118.jpg: (740880,)
# LBP features shape for horse-118.jpg: (26,)
# HOG features shape for horse-119.jpg: (749700,)
# LBP features shape for horse-119.jpg: (26,)
# HOG features shape for horse-12.jpg: (222264,)
# LBP features shape for horse-12.jpg: (26,)
# HOG features shape for horse-120.jpg: (749700,)
# LBP features shape for horse-120.jpg: (26,)
# HOG features shape for horse-121.jpg: (689724,)
# LBP features shape for horse-121.jpg: (26,)
# HOG features shape for horse-122.jpg: (714420,)
# LBP features shape for horse-122.jpg: (26,)
# HOG features shape for horse-123.jpg: (770868,)
# LBP features shape for horse-123.jpg: (26,)
# HOG features shape for horse-124.jpg: (737352,)
# LBP features shape for horse-124.jpg: (26,)
# HOG features shape for horse-125.jpg: (719712,)
# LBP features shape for horse-125.jpg: (26,)
# HOG features shape for horse-126.jpg: (740880,)
# LBP features shape for horse-126.jpg: (26,)
# HOG features shape for horse-127.jpg: (777924,)
# LBP features shape for horse-127.jpg: (26,)
# HOG features shape for horse-128.jpg: (714420,)
# LBP features shape for horse-128.jpg: (26,)
# HOG features shape for horse-129.jpg: (719712,)
# LBP features shape for horse-129.jpg: (26,)
# HOG features shape for horse-13.jpg: (18712512,)
# LBP features shape for horse-13.jpg: (26,)
# HOG features shape for horse-130.jpg: (359856,)
# LBP features shape for horse-130.jpg: (26,)
# HOG features shape for horse-131.jpg: (714420,)
# LBP features shape for horse-131.jpg: (26,)
# HOG features shape for horse-132.jpg: (714420,)
# LBP features shape for horse-132.jpg: (26,)
# HOG features shape for horse-133.jpg: (733824,)
# LBP features shape for horse-133.jpg: (26,)
# HOG features shape for horse-134.jpg: (749700,)
# LBP features shape for horse-134.jpg: (26,)
# HOG features shape for horse-135.jpg: (687960,)
# LBP features shape for horse-135.jpg: (26,)
# HOG features shape for horse-136.jpg: (749700,)
# LBP features shape for horse-136.jpg: (26,)
# HOG features shape for horse-137.jpg: (740880,)
# LBP features shape for horse-137.jpg: (26,)
# HOG features shape for horse-138.jpg: (714420,)
# LBP features shape for horse-138.jpg: (26,)
# HOG features shape for horse-139.jpg: (714420,)
# LBP features shape for horse-139.jpg: (26,)
# HOG features shape for horse-14.jpg: (14750568,)
# LBP features shape for horse-14.jpg: (26,)
# HOG features shape for horse-140.jpg: (740880,)
# LBP features shape for horse-140.jpg: (26,)
# HOG features shape for horse-141.jpg: (714420,)
# LBP features shape for horse-141.jpg: (26,)
# HOG features shape for horse-142.jpg: (749700,)
# LBP features shape for horse-142.jpg: (26,)
# HOG features shape for horse-143.jpg: (749700,)
# LBP features shape for horse-143.jpg: (26,)
# HOG features shape for horse-144.jpg: (749700,)
# LBP features shape for horse-144.jpg: (26,)
# HOG features shape for horse-145.jpg: (740880,)
# LBP features shape for horse-145.jpg: (26,)
# HOG features shape for horse-146.jpg: (714420,)
# LBP features shape for horse-146.jpg: (26,)
# HOG features shape for horse-147.jpg: (762048,)
# LBP features shape for horse-147.jpg: (26,)
# HOG features shape for horse-148.jpg: (762048,)
# LBP features shape for horse-148.jpg: (26,)
# HOG features shape for horse-149.jpg: (719712,)
# LBP features shape for horse-149.jpg: (26,)
# HOG features shape for horse-15.jpg: (48684636,)
# LBP features shape for horse-15.jpg: (26,)
# HOG features shape for horse-150.jpg: (777924,)
# LBP features shape for horse-150.jpg: (26,)
# HOG features shape for horse-16.jpg: (16648632,)
# LBP features shape for horse-16.jpg: (26,)
# HOG features shape for horse-17.jpg: (52609536,)
# LBP features shape for horse-17.jpg: (26,)
# HOG features shape for horse-18.jpg: (710892,)
# LBP features shape for horse-18.jpg: (26,)
# HOG features shape for horse-19.jpg: (749700,)
# LBP features shape for horse-19.jpg: (26,)
# HOG features shape for horse-2.jpg: (4581108,)
# LBP features shape for horse-2.jpg: (26,)
# HOG features shape for horse-20.jpg: (740880,)
# LBP features shape for horse-20.jpg: (26,)
# HOG features shape for horse-21.jpg: (749700,)
# LBP features shape for horse-21.jpg: (26,)
# HOG features shape for horse-22.jpg: (733824,)
# LBP features shape for horse-22.jpg: (26,)
# HOG features shape for horse-23.jpg: (749700,)
# LBP features shape for horse-23.jpg: (26,)
# HOG features shape for horse-24.jpg: (777924,)
# LBP features shape for horse-24.jpg: (26,)
# HOG features shape for horse-25.jpg: (527436,)
# LBP features shape for horse-25.jpg: (26,)
# HOG features shape for horse-26.jpg: (762048,)
# LBP features shape for horse-26.jpg: (26,)
# HOG features shape for horse-27.jpg: (730296,)
# LBP features shape for horse-27.jpg: (26,)
# HOG features shape for horse-28.jpg: (714420,)
# LBP features shape for horse-28.jpg: (26,)
# HOG features shape for horse-29.jpg: (714420,)
# LBP features shape for horse-29.jpg: (26,)
# HOG features shape for horse-3.jpg: (1319472,)
# LBP features shape for horse-3.jpg: (26,)
# HOG features shape for horse-30.jpg: (749700,)
# LBP features shape for horse-30.jpg: (26,)
# HOG features shape for horse-31.jpg: (777924,)
# LBP features shape for horse-31.jpg: (26,)
# HOG features shape for horse-32.jpg: (749700,)
# LBP features shape for horse-32.jpg: (26,)
# HOG features shape for horse-33.jpg: (770868,)
# LBP features shape for horse-33.jpg: (26,)
# HOG features shape for horse-34.jpg: (730296,)
# LBP features shape for horse-34.jpg: (26,)
# HOG features shape for horse-35.jpg: (749700,)
# LBP features shape for horse-35.jpg: (26,)
# HOG features shape for horse-36.jpg: (733824,)
# LBP features shape for horse-36.jpg: (26,)
# HOG features shape for horse-37.jpg: (714420,)
# LBP features shape for horse-37.jpg: (26,)
# HOG features shape for horse-38.jpg: (714420,)
# LBP features shape for horse-38.jpg: (26,)
# HOG features shape for horse-39.jpg: (714420,)
# LBP features shape for horse-39.jpg: (26,)
# HOG features shape for horse-4.jpg: (1435896,)
# LBP features shape for horse-4.jpg: (26,)
# HOG features shape for horse-40.jpg: (740880,)
# LBP features shape for horse-40.jpg: (26,)
# HOG features shape for horse-41.jpg: (740880,)
# LBP features shape for horse-41.jpg: (26,)
# HOG features shape for horse-42.jpg: (733824,)
# LBP features shape for horse-42.jpg: (26,)
# HOG features shape for horse-43.jpg: (714420,)
# LBP features shape for horse-43.jpg: (26,)
# HOG features shape for horse-44.jpg: (770868,)
# LBP features shape for horse-44.jpg: (26,)
# HOG features shape for horse-45.jpg: (749700,)
# LBP features shape for horse-45.jpg: (26,)
# HOG features shape for horse-46.jpg: (762048,)
# LBP features shape for horse-46.jpg: (26,)
# HOG features shape for horse-47.jpg: (740880,)
# LBP features shape for horse-47.jpg: (26,)
# HOG features shape for horse-48.jpg: (733824,)
# LBP features shape for horse-48.jpg: (26,)
# HOG features shape for horse-49.jpg: (733824,)
# LBP features shape for horse-49.jpg: (26,)
# HOG features shape for horse-5.jpg: (749700,)
# LBP features shape for horse-5.jpg: (26,)
# HOG features shape for horse-50.jpg: (740880,)
# LBP features shape for horse-50.jpg: (26,)
# HOG features shape for horse-51.jpg: (740880,)
# LBP features shape for horse-51.jpg: (26,)
# HOG features shape for horse-52.jpg: (740880,)
# LBP features shape for horse-52.jpg: (26,)
# HOG features shape for horse-53.jpg: (740880,)
# LBP features shape for horse-53.jpg: (26,)
# HOG features shape for horse-54.jpg: (740880,)
# LBP features shape for horse-54.jpg: (26,)
# HOG features shape for horse-55.jpg: (714420,)
# LBP features shape for horse-55.jpg: (26,)
# HOG features shape for horse-56.jpg: (749700,)
# LBP features shape for horse-56.jpg: (26,)
# HOG features shape for horse-57.jpg: (740880,)
# LBP features shape for horse-57.jpg: (26,)
# HOG features shape for horse-58.jpg: (652680,)
# LBP features shape for horse-58.jpg: (26,)
# HOG features shape for horse-59.jpg: (770868,)
# LBP features shape for horse-59.jpg: (26,)
# HOG features shape for horse-6.jpg: (2734200,)
# LBP features shape for horse-6.jpg: (26,)
# HOG features shape for horse-60.jpg: (749700,)
# LBP features shape for horse-60.jpg: (26,)
# HOG features shape for horse-61.jpg: (740880,)
# LBP features shape for horse-61.jpg: (26,)
# HOG features shape for horse-62.jpg: (677376,)
# LBP features shape for horse-62.jpg: (26,)
# HOG features shape for horse-63.jpg: (749700,)
# LBP features shape for horse-63.jpg: (26,)
# HOG features shape for horse-64.jpg: (714420,)
# LBP features shape for horse-64.jpg: (26,)
# HOG features shape for horse-65.jpg: (749700,)
# LBP features shape for horse-65.jpg: (26,)
# HOG features shape for horse-66.jpg: (740880,)
# LBP features shape for horse-66.jpg: (26,)
# HOG features shape for horse-67.jpg: (762048,)
# LBP features shape for horse-67.jpg: (26,)
# HOG features shape for horse-68.jpg: (762048,)
# LBP features shape for horse-68.jpg: (26,)
# HOG features shape for horse-69.jpg: (714420,)
# LBP features shape for horse-69.jpg: (26,)
# HOG features shape for horse-7.jpg: (3783780,)
# LBP features shape for horse-7.jpg: (26,)
# HOG features shape for horse-70.jpg: (777924,)
# LBP features shape for horse-70.jpg: (26,)
# HOG features shape for horse-71.jpg: (749700,)
# LBP features shape for horse-71.jpg: (26,)
# HOG features shape for horse-72.jpg: (740880,)
# LBP features shape for horse-72.jpg: (26,)
# HOG features shape for horse-73.jpg: (762048,)
# LBP features shape for horse-73.jpg: (26,)
# HOG features shape for horse-74.jpg: (733824,)
# LBP features shape for horse-74.jpg: (26,)
# HOG features shape for horse-75.jpg: (269892,)
# LBP features shape for horse-75.jpg: (26,)
# HOG features shape for horse-76.jpg: (749700,)
# LBP features shape for horse-76.jpg: (26,)
# HOG features shape for horse-77.jpg: (749700,)
# LBP features shape for horse-77.jpg: (26,)
# HOG features shape for horse-78.jpg: (714420,)
# LBP features shape for horse-78.jpg: (26,)
# HOG features shape for horse-79.jpg: (770868,)
# LBP features shape for horse-79.jpg: (26,)
# HOG features shape for horse-8.jpg: (740880,)
# LBP features shape for horse-8.jpg: (26,)
# HOG features shape for horse-80.jpg: (749700,)
# LBP features shape for horse-80.jpg: (26,)
# HOG features shape for horse-81.jpg: (730296,)
# LBP features shape for horse-81.jpg: (26,)
# HOG features shape for horse-82.jpg: (719712,)
# LBP features shape for horse-82.jpg: (26,)
# HOG features shape for horse-83.jpg: (749700,)
# LBP features shape for horse-83.jpg: (26,)
# HOG features shape for horse-84.jpg: (770868,)
# LBP features shape for horse-84.jpg: (26,)
# HOG features shape for horse-85.jpg: (733824,)
# LBP features shape for horse-85.jpg: (26,)
# HOG features shape for horse-86.jpg: (740880,)
# LBP features shape for horse-86.jpg: (26,)
# HOG features shape for horse-87.jpg: (749700,)
# LBP features shape for horse-87.jpg: (26,)
# HOG features shape for horse-88.jpg: (740880,)
# LBP features shape for horse-88.jpg: (26,)
# HOG features shape for horse-89.jpg: (733824,)
# LBP features shape for horse-89.jpg: (26,)
# HOG features shape for horse-9.jpg: (5397840,)
# LBP features shape for horse-9.jpg: (26,)
# HOG features shape for horse-90.jpg: (749700,)
# LBP features shape for horse-90.jpg: (26,)
# HOG features shape for horse-91.jpg: (740880,)
# LBP features shape for horse-91.jpg: (26,)
# HOG features shape for horse-92.jpg: (740880,)
# LBP features shape for horse-92.jpg: (26,)
# HOG features shape for horse-93.jpg: (762048,)
# LBP features shape for horse-93.jpg: (26,)
# HOG features shape for horse-94.jpg: (714420,)
# LBP features shape for horse-94.jpg: (26,)
# HOG features shape for horse-95.jpg: (687960,)
# LBP features shape for horse-95.jpg: (26,)
# HOG features shape for horse-96.jpg: (749700,)
# LBP features shape for horse-96.jpg: (26,)
# HOG features shape for horse-97.jpg: (749700,)
# LBP features shape for horse-97.jpg: (26,)
# HOG features shape for horse-98.jpg: (714420,)
# LBP features shape for horse-98.jpg: (26,)
# HOG features shape for horse-99.jpg: (749700,)
# LBP features shape for horse-99.jpg: (26,)

# %% [markdown]
# Utilize pre-trained deep Convolutional Neural Networks (CNNs) from TensorFlow's Keras API for
# feature extraction. Describe how you would extract deep CNN features from images.

# %% [markdown]
# To extract deep Convolutional Neural Network (CNN) features from images,
#
# - Choose a Pre-trained CNN Model: Select a pre-trained CNN model suitable. Common choices include VGG16, VGG19, ResNet, Inception, etc. These models are trained on large-scale datasets like ImageNet and have learned to extract high-level features from images.
#
# - Load the Pre-trained Model: Use TensorFlow's Keras API to load the pre-trained model. This is done with a single line of code using functions like VGG16() or ResNet50().
#
# - Prepare the Image: Load the image using a suitable image loading function such as tensorflow.keras.preprocessing.image.load_img(). Resize the image to match the input size expected by the model (e.g., 224x224 pixels for VGG16).
#
# - Preprocess the Image: Convert the image to an array using tensorflow.keras.preprocessing.image.img_to_array(). Expand the dimensions of the image array to create a batch of size 1. Preprocess the image data to match the input preprocessing used during the training of the CNN model. This typically involves normalization.
#
# - Extract Features: Pass the preprocessed image through the loaded CNN model using model.predict(). This will extract features from the image at one of the intermediate layers of the CNN, depending on your choice. The earlier layers capture low-level features like edges and textures, while deeper layers capture higher-level features.
#
# - Use Extracted Features: The output of model.predict() will be a feature vector representing the image in the feature space of the CNN. This vector can be used as input to identify tasks such as classification, object detection, or image retrieval.

# %%
import os
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
import numpy as np

data_folder = 'C:/Users/soban/Desktop/CV/data'
folders = ['cats', 'dogs', 'horses']

def extract_cnn_features(img_path, model):
    img = image.load_img(img_path, target_size=(224, 224)) #resizing the image to the target size of (224,224) pixels since it is the input size expected by the model
    img_data = image.img_to_array(img) 
    img_data = np.expand_dims(img_data, axis=0) #expanding the dimensions of the image array size
    img_data = preprocess_input(img_data)
    features = model.predict(img_data) #passing the preprocessed image to the model using predict, this will generate features corresponding to the input image
    return features

# for this code we are using pre-trained CNN Model known as VGG-16
base_model = VGG16(weights='imagenet')  #This line loads the pre-trained VGG16 model from Keras with weights pre-trained on the ImageNet dataset.
#When weights parameter is set to 'imagenet', it initializes the model with weights that were trained on ImageNet, a large dataset with millions of images across thousands of classes.

model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output) #this line is used to output the activations of the layer named fc1.
#this layer represents the first fully connected layer of vgg16 that contains high level features learned by the network.

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        features = extract_cnn_features(img_path, model)
        
        print(f'CNN features shape for {img_name}: {features.shape}')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 635ms/step
# CNN features shape for cat.1.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 393ms/step
# CNN features shape for cat.10.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step
# CNN features shape for cat.100.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 399ms/step
# CNN features shape for cat.101.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# CNN features shape for cat.102.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# CNN features shape for cat.103.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# CNN features shape for cat.104.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# CNN features shape for cat.105.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 391ms/step
# CNN features shape for cat.106.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# CNN features shape for cat.107.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# CNN features shape for cat.108.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# CNN features shape for cat.109.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 400ms/step
# CNN features shape for cat.11.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 415ms/step
# CNN features shape for cat.110.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# CNN features shape for cat.111.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# CNN features shape for cat.112.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 441ms/step
# CNN features shape for cat.113.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# CNN features shape for cat.114.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# CNN features shape for cat.115.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 420ms/step
# CNN features shape for cat.116.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 410ms/step
# CNN features shape for cat.117.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 413ms/step
# CNN features shape for cat.118.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 419ms/step
# CNN features shape for cat.119.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 429ms/step
# CNN features shape for cat.12.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 421ms/step
# CNN features shape for cat.120.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 394ms/step
# CNN features shape for cat.121.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# CNN features shape for cat.122.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# CNN features shape for cat.123.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# CNN features shape for cat.124.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# CNN features shape for cat.125.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 406ms/step
# CNN features shape for cat.126.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# CNN features shape for cat.127.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step
# CNN features shape for cat.128.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 404ms/step
# CNN features shape for cat.129.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# CNN features shape for cat.13.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# CNN features shape for cat.130.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# CNN features shape for cat.131.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 403ms/step
# CNN features shape for cat.132.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# CNN features shape for cat.133.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 442ms/step
# CNN features shape for cat.134.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# CNN features shape for cat.135.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 418ms/step
# CNN features shape for cat.136.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# CNN features shape for cat.137.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# CNN features shape for cat.138.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# CNN features shape for cat.139.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# CNN features shape for cat.14.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for cat.140.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# CNN features shape for cat.141.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for cat.142.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# CNN features shape for cat.143.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 434ms/step
# CNN features shape for cat.144.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# CNN features shape for cat.145.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# CNN features shape for cat.146.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for cat.147.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# CNN features shape for cat.148.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# CNN features shape for cat.149.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# CNN features shape for cat.15.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 408ms/step
# CNN features shape for cat.150.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for cat.151.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# CNN features shape for cat.152.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# CNN features shape for cat.153.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 423ms/step
# CNN features shape for cat.154.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# CNN features shape for cat.155.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# CNN features shape for cat.156.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 416ms/step
# CNN features shape for cat.157.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step
# CNN features shape for cat.158.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# CNN features shape for cat.159.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 432ms/step
# CNN features shape for cat.16.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# CNN features shape for cat.160.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for cat.161.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# CNN features shape for cat.162.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 411ms/step
# CNN features shape for cat.163.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 438ms/step
# CNN features shape for cat.164.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# CNN features shape for cat.165.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for cat.166.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# CNN features shape for cat.167.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for cat.168.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# CNN features shape for cat.169.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# CNN features shape for cat.17.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 439ms/step
# CNN features shape for cat.170.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for cat.171.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 433ms/step
# CNN features shape for cat.172.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 428ms/step
# CNN features shape for cat.173.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for cat.174.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 450ms/step
# CNN features shape for cat.175.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# CNN features shape for cat.176.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# CNN features shape for cat.177.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# CNN features shape for cat.178.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# CNN features shape for cat.179.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for cat.18.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# CNN features shape for cat.180.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# CNN features shape for cat.181.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 436ms/step
# CNN features shape for cat.182.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# CNN features shape for cat.183.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for cat.184.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# CNN features shape for cat.185.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# CNN features shape for cat.186.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# CNN features shape for cat.187.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 431ms/step
# CNN features shape for cat.188.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# CNN features shape for cat.189.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for cat.19.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for cat.190.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 453ms/step
# CNN features shape for cat.191.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# CNN features shape for cat.192.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for cat.193.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# CNN features shape for cat.194.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# CNN features shape for cat.195.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 448ms/step
# CNN features shape for cat.196.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# CNN features shape for cat.197.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# CNN features shape for cat.198.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 462ms/step
# CNN features shape for cat.199.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for cat.2.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# CNN features shape for cat.20.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# CNN features shape for cat.200.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# CNN features shape for cat.21.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for cat.22.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for cat.23.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for cat.24.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 446ms/step
# CNN features shape for cat.25.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for cat.26.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# CNN features shape for cat.27.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for cat.28.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# CNN features shape for cat.29.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for cat.3.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for cat.30.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for cat.31.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# CNN features shape for cat.32.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# CNN features shape for cat.33.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 556ms/step
# CNN features shape for cat.34.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for cat.35.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for cat.36.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for cat.37.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# CNN features shape for cat.38.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# CNN features shape for cat.39.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# CNN features shape for cat.4.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# CNN features shape for cat.40.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# CNN features shape for cat.41.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# CNN features shape for cat.42.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for cat.43.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for cat.44.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for cat.45.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for cat.46.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 455ms/step
# CNN features shape for cat.47.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for cat.48.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# CNN features shape for cat.49.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# CNN features shape for cat.5.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# CNN features shape for cat.50.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# CNN features shape for cat.51.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# CNN features shape for cat.52.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# CNN features shape for cat.53.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for cat.54.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# CNN features shape for cat.55.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# CNN features shape for cat.56.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for cat.57.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for cat.58.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for cat.59.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for cat.6.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for cat.60.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# CNN features shape for cat.61.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 456ms/step
# CNN features shape for cat.62.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# CNN features shape for cat.63.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# CNN features shape for cat.64.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for cat.65.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# CNN features shape for cat.66.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# CNN features shape for cat.67.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for cat.68.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for cat.69.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for cat.7.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# CNN features shape for cat.70.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for cat.71.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for cat.72.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for cat.73.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# CNN features shape for cat.74.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# CNN features shape for cat.75.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 526ms/step
# CNN features shape for cat.76.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# CNN features shape for cat.77.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for cat.78.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# CNN features shape for cat.79.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# CNN features shape for cat.8.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# CNN features shape for cat.80.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for cat.81.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# CNN features shape for cat.82.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for cat.83.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# CNN features shape for cat.84.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for cat.85.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for cat.86.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for cat.87.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for cat.88.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# CNN features shape for cat.89.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# CNN features shape for cat.9.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for cat.90.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for cat.91.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for cat.92.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# CNN features shape for cat.93.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for cat.94.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# CNN features shape for cat.95.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for cat.96.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# CNN features shape for cat.97.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for cat.98.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# CNN features shape for cat.99.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 457ms/step
# CNN features shape for augmented_0.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for augmented_1.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# CNN features shape for augmented_10.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for augmented_11.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for augmented_12.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for augmented_13.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for augmented_14.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# CNN features shape for augmented_15.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# CNN features shape for augmented_16.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for augmented_17.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# CNN features shape for augmented_18.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for augmented_19.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for augmented_2.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# CNN features shape for augmented_20.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for augmented_21.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for augmented_22.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for augmented_23.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# CNN features shape for augmented_24.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for augmented_25.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for augmented_26.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for augmented_27.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for augmented_28.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for augmented_29.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# CNN features shape for augmented_3.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for augmented_30.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# CNN features shape for augmented_31.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for augmented_32.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for augmented_33.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# CNN features shape for augmented_34.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for augmented_35.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for augmented_36.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# CNN features shape for augmented_37.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for augmented_38.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for augmented_39.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for augmented_4.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for augmented_40.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for augmented_41.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for augmented_42.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 458ms/step
# CNN features shape for augmented_43.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# CNN features shape for augmented_44.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# CNN features shape for augmented_45.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# CNN features shape for augmented_46.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for augmented_47.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# CNN features shape for augmented_48.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for augmented_49.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for augmented_5.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for augmented_50.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for augmented_51.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for augmented_52.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# CNN features shape for augmented_53.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for augmented_54.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for augmented_55.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# CNN features shape for augmented_56.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for augmented_57.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# CNN features shape for augmented_58.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# CNN features shape for augmented_59.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for augmented_6.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# CNN features shape for augmented_60.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# CNN features shape for augmented_61.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for augmented_62.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# CNN features shape for augmented_63.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# CNN features shape for augmented_64.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for augmented_65.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for augmented_66.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# CNN features shape for augmented_67.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for augmented_68.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for augmented_69.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for augmented_7.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# CNN features shape for augmented_70.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for augmented_71.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# CNN features shape for augmented_72.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for augmented_73.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for augmented_74.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for augmented_75.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for augmented_76.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 530ms/step
# CNN features shape for augmented_77.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 519ms/step
# CNN features shape for augmented_78.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# CNN features shape for augmented_79.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# CNN features shape for augmented_8.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for augmented_80.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# CNN features shape for augmented_81.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for augmented_82.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for augmented_83.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 467ms/step
# CNN features shape for augmented_84.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for augmented_85.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# CNN features shape for augmented_86.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# CNN features shape for augmented_87.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for augmented_88.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# CNN features shape for augmented_89.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# CNN features shape for augmented_9.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# CNN features shape for augmented_90.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for augmented_91.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for augmented_92.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for augmented_93.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for augmented_94.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for augmented_95.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# CNN features shape for augmented_96.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# CNN features shape for augmented_97.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# CNN features shape for augmented_98.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 461ms/step
# CNN features shape for augmented_99.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for dog.1.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for dog.10.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for dog.100.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# CNN features shape for dog.11.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# CNN features shape for dog.12.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for dog.13.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for dog.14.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# CNN features shape for dog.15.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 525ms/step
# CNN features shape for dog.16.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# CNN features shape for dog.17.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for dog.18.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# CNN features shape for dog.19.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for dog.2.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for dog.20.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for dog.21.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# CNN features shape for dog.22.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# CNN features shape for dog.23.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# CNN features shape for dog.24.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# CNN features shape for dog.25.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# CNN features shape for dog.26.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# CNN features shape for dog.27.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 470ms/step
# CNN features shape for dog.28.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# CNN features shape for dog.29.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for dog.3.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# CNN features shape for dog.30.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for dog.31.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# CNN features shape for dog.32.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for dog.33.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 548ms/step
# CNN features shape for dog.34.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for dog.35.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for dog.36.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for dog.37.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for dog.38.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# CNN features shape for dog.39.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# CNN features shape for dog.4.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# CNN features shape for dog.40.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# CNN features shape for dog.41.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for dog.42.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# CNN features shape for dog.43.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# CNN features shape for dog.44.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# CNN features shape for dog.45.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for dog.46.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for dog.47.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for dog.48.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for dog.49.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for dog.5.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# CNN features shape for dog.50.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for dog.51.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 459ms/step
# CNN features shape for dog.52.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for dog.53.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for dog.54.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for dog.55.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for dog.56.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 546ms/step
# CNN features shape for dog.57.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for dog.58.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# CNN features shape for dog.59.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for dog.6.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for dog.60.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for dog.61.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for dog.62.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# CNN features shape for dog.63.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for dog.64.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for dog.65.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for dog.66.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for dog.67.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 544ms/step
# CNN features shape for dog.68.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 516ms/step
# CNN features shape for dog.69.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# CNN features shape for dog.7.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 477ms/step
# CNN features shape for dog.70.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for dog.71.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# CNN features shape for dog.72.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# CNN features shape for dog.73.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for dog.74.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# CNN features shape for dog.75.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for dog.76.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for dog.77.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for dog.78.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for dog.79.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# CNN features shape for dog.8.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for dog.80.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# CNN features shape for dog.81.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# CNN features shape for dog.82.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for dog.83.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# CNN features shape for dog.84.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for dog.85.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for dog.86.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# CNN features shape for dog.87.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for dog.88.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for dog.89.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for dog.9.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for dog.90.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# CNN features shape for dog.91.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# CNN features shape for dog.92.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for dog.93.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for dog.94.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for dog.95.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# CNN features shape for dog.96.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for dog.97.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for dog.98.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# CNN features shape for dog.99.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for augmented_0.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# CNN features shape for augmented_1.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# CNN features shape for augmented_10.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for augmented_11.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for augmented_12.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for augmented_13.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 520ms/step
# CNN features shape for augmented_14.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for augmented_15.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# CNN features shape for augmented_16.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# CNN features shape for augmented_17.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# CNN features shape for augmented_18.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# CNN features shape for augmented_19.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# CNN features shape for augmented_2.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 532ms/step
# CNN features shape for augmented_20.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for augmented_21.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for augmented_22.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for augmented_23.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for augmented_24.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for augmented_25.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for augmented_26.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 537ms/step
# CNN features shape for augmented_27.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for augmented_28.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for augmented_29.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# CNN features shape for augmented_3.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for augmented_30.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for augmented_31.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for augmented_32.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for augmented_33.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for augmented_34.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for augmented_35.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# CNN features shape for augmented_36.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for augmented_37.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# CNN features shape for augmented_38.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# CNN features shape for augmented_39.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# CNN features shape for augmented_4.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for augmented_40.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# CNN features shape for augmented_41.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for augmented_42.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for augmented_43.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for augmented_44.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for augmented_45.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 527ms/step
# CNN features shape for augmented_46.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for augmented_47.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# CNN features shape for augmented_48.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for augmented_49.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 513ms/step
# CNN features shape for augmented_5.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# CNN features shape for augmented_6.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for augmented_7.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for augmented_8.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for augmented_9.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for horse-1.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for horse-10.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for horse-100.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# CNN features shape for horse-101.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for horse-102.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for horse-103.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# CNN features shape for horse-104.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# CNN features shape for horse-105.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# CNN features shape for horse-106.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for horse-107.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# CNN features shape for horse-108.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for horse-109.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for horse-11.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# CNN features shape for horse-110.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for horse-111.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for horse-112.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for horse-113.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# CNN features shape for horse-114.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for horse-115.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# CNN features shape for horse-116.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for horse-117.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# CNN features shape for horse-118.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 521ms/step
# CNN features shape for horse-119.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 499ms/step
# CNN features shape for horse-12.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for horse-120.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# CNN features shape for horse-121.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for horse-122.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for horse-123.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for horse-124.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 522ms/step
# CNN features shape for horse-125.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for horse-126.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 504ms/step
# CNN features shape for horse-127.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 518ms/step
# CNN features shape for horse-128.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for horse-129.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 505ms/step
# CNN features shape for horse-13.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for horse-130.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for horse-131.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# CNN features shape for horse-132.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# CNN features shape for horse-133.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# CNN features shape for horse-134.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for horse-135.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# CNN features shape for horse-136.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for horse-137.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 524ms/step
# CNN features shape for horse-138.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# CNN features shape for horse-139.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for horse-14.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 506ms/step
# CNN features shape for horse-140.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for horse-141.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 511ms/step
# CNN features shape for horse-142.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for horse-143.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# CNN features shape for horse-144.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 523ms/step
# CNN features shape for horse-145.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 514ms/step
# CNN features shape for horse-146.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# CNN features shape for horse-147.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for horse-148.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 500ms/step
# CNN features shape for horse-149.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for horse-15.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 508ms/step
# CNN features shape for horse-150.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for horse-16.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 535ms/step
# CNN features shape for horse-17.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 528ms/step
# CNN features shape for horse-18.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 507ms/step
# CNN features shape for horse-19.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 529ms/step
# CNN features shape for horse-2.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for horse-20.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 515ms/step
# CNN features shape for horse-21.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step
# CNN features shape for horse-22.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# CNN features shape for horse-23.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# CNN features shape for horse-24.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# CNN features shape for horse-25.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for horse-26.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 487ms/step
# CNN features shape for horse-27.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for horse-28.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for horse-29.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# CNN features shape for horse-3.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 510ms/step
# CNN features shape for horse-30.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 503ms/step
# CNN features shape for horse-31.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for horse-32.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for horse-33.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for horse-34.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for horse-35.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for horse-36.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 488ms/step
# CNN features shape for horse-37.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for horse-38.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 502ms/step
# CNN features shape for horse-39.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for horse-4.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 444ms/step
# CNN features shape for horse-40.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 460ms/step
# CNN features shape for horse-41.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 501ms/step
# CNN features shape for horse-42.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for horse-43.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 471ms/step
# CNN features shape for horse-44.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for horse-45.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# CNN features shape for horse-46.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for horse-47.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for horse-48.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for horse-49.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for horse-5.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for horse-50.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for horse-51.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for horse-52.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 490ms/step
# CNN features shape for horse-53.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for horse-54.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for horse-55.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for horse-56.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for horse-57.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 480ms/step
# CNN features shape for horse-58.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 489ms/step
# CNN features shape for horse-59.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for horse-6.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for horse-60.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for horse-61.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 493ms/step
# CNN features shape for horse-62.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# CNN features shape for horse-63.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for horse-64.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for horse-65.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for horse-66.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 479ms/step
# CNN features shape for horse-67.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 495ms/step
# CNN features shape for horse-68.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for horse-69.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 483ms/step
# CNN features shape for horse-7.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for horse-70.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 484ms/step
# CNN features shape for horse-71.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for horse-72.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# CNN features shape for horse-73.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 464ms/step
# CNN features shape for horse-74.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# CNN features shape for horse-75.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for horse-76.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 472ms/step
# CNN features shape for horse-77.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 466ms/step
# CNN features shape for horse-78.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 485ms/step
# CNN features shape for horse-79.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# CNN features shape for horse-8.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# CNN features shape for horse-80.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 478ms/step
# CNN features shape for horse-81.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for horse-82.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 475ms/step
# CNN features shape for horse-83.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step
# CNN features shape for horse-84.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 468ms/step
# CNN features shape for horse-85.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for horse-86.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 494ms/step
# CNN features shape for horse-87.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 486ms/step
# CNN features shape for horse-88.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 476ms/step
# CNN features shape for horse-89.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for horse-9.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 463ms/step
# CNN features shape for horse-90.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 481ms/step
# CNN features shape for horse-91.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 509ms/step
# CNN features shape for horse-92.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 491ms/step
# CNN features shape for horse-93.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 473ms/step
# CNN features shape for horse-94.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# CNN features shape for horse-95.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for horse-96.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 474ms/step
# CNN features shape for horse-97.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 482ms/step
# CNN features shape for horse-98.jpg: (1, 4096)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 497ms/step
# CNN features shape for horse-99.jpg: (1, 4096)

# %% [markdown]
# # 3) Dimensionality Reduction with NumPy and scikit-learn

# %% [markdown]
# PCA is effective in reducing the feature space while retaining as much variance as possible. However, it does not explicitly consider class labels, so it may not preserve class discriminative information optimally.
# LDA explicitly models the class labels and aims to find a lower-dimensional space where the classes are well-separated. It often outperforms PCA in preserving class discriminative information.
# QDA can capture more complex relationships between features and class labels compared to LDA. It may be more effective when the underlying data distributions are non-linear or when classes have different covariance structures.
# In summary, while PCA is effective in reducing the feature space, it may not preserve class discriminative information optimally compared to LDA and QDA. LDA explicitly considers class labels and is effective when classes are well-separated linearly. QDA extends LDA to handle non-linear relationships and different covariance structures among classes, making it suitable for more complex data distributions. The choice of method depends on the specific characteristics of the data.

# %% [markdown]
# **Independent Component Analysis (ICA)** in image processing separates mixed images into their original independent components. It's like unmixing a picture made of overlapping textures, objects, or lighting conditions. ICA helps isolate textures, recognize objects, remove lighting effects, and decompose images for analysis or fusion. It uncovers hidden factors assuming they are statistically independent, aiding tasks like image enhancement and pattern recognition."

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA, QuadraticDiscriminantAnalysis as QDA
import os
import cv2
from skimage.feature import local_binary_pattern
from skimage.transform import resize
import tensorflow as tf
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model

# Define functions to compute HOG and LBP features
def compute_hog_features(image):
    win_size = (64, 64)
    block_size = (16, 16)
    block_stride = (8, 8)
    cell_size = (8, 8)
    nbins = 9

    hog = cv2.HOGDescriptor(win_size, block_size, block_stride, cell_size, nbins)
    h = hog.compute(image)
    return h

def compute_lbp_features(image):
    radius = 3
    n_points = 8 * radius  # Number of sampling points
    lbp = local_binary_pattern(image, n_points, radius, method='uniform')
    (hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    return hist

# Load pre-trained VGG16 model for CNN feature extraction
base_model = VGG16(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

# Define data folders and process images
data_folder = 'C:/Users/soban/Desktop/CV/data'
folders = ['cats', 'dogs', 'horses']

X = []
y = []

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        image = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)
        
        if image is not None:
            resized_image = resize(image, (64, 64)).astype(np.uint8)
            
            hog_features = compute_hog_features(resized_image)
            lbp_features = compute_lbp_features(resized_image)
            
            combined_features = np.hstack((hog_features.flatten(), lbp_features.flatten()))
            
            X.append(combined_features)
            y.append(folder)

X = np.array(X)
y = np.array(y)

# Principal Component Analysis (PCA)
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X)
print(f"PCA components shape: {X_pca.shape}")

# Linear Discriminant Analysis (LDA)
lda = LDA(n_components=2)
X_lda = lda.fit_transform(X, y)
print(f"LDA components shape: {X_lda.shape}")

# Quadratic Discriminant Analysis (QDA)
qda = QDA()
qda.fit(X, y)
predictions = qda.predict(X)
print(f"QDA predictions: {predictions[:5]}")
# Out:
# PCA components shape: (600, 2)
# LDA components shape: (600, 2)
# QDA predictions: ['dogs' 'dogs' 'dogs' 'dogs' 'dogs']
# C:\Users\soban\anaconda3\Lib\site-packages\sklearn\discriminant_analysis.py:926: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %% [markdown]
# # 4) Classification using SVM with scikit-learn

# %% [markdown]
# Working of SVM
# Linear SVM:
#
# For linearly separable data, SVM finds the hyperplane that maximizes the margin between classes.
# The decision function is determined by the dot product of feature vectors and a weight vector plus a bias term.
# The goal is to minimize the hinge loss, which penalizes misclassifications.
#
# Non-linear SVM:
# SVM can be extended to handle non-linearly separable data by using kernel functions.
# Kernel functions transform the input features into a higher-dimensional space, where the classes might become separable by a hyperplane.
# Common kernel functions include polynomial, radial basis function (RBF), and sigmoid kernels.
#
# Suitability for Image Classification
# SVMs are suitable for image classification tasks for several reasons:
#
# Effective with Reduced Feature Spaces: SVMs can handle high-dimensional feature spaces efficiently, making them suitable for image data.
# Robustness to Overfitting: SVMs are less prone to overfitting, especially when using regularization parameters.
# Kernel Trick for Non-linearity: SVMs can handle non-linear decision boundaries using kernel functions, which is useful for image data with complex class distributions.

# %% [markdown]
# Training an SVM Classifier with Reduced Feature Spaces

# %%
import os
import cv2
import numpy as np
from skimage.feature import local_binary_pattern
from skimage.transform import resize
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

def compute_hog_features(image):
    win_size = (64, 64)
    block_size = (16, 16)
    block_stride = (8, 8)
    cell_size = (8, 8)
    nbins = 9

    hog = cv2.HOGDescriptor(win_size, block_size, block_stride, cell_size, nbins)
    h = hog.compute(image)
    return h.flatten()

def compute_lbp_features(image):
    radius = 3
    n_points = 8 * radius  # Number of sampling points
    lbp = local_binary_pattern(image, n_points, radius, method='uniform')
    (hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    return hist.flatten()

# Function to preprocess an image
def preprocess_image(img_path):
    # Load image using OpenCV
    img = cv2.imread(img_path)
    if img is None:
        raise FileNotFoundError(f"Image not found at path: {img_path}")

    gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    normalized_image = cv2.normalize(gray_image, None, 0, 255, cv2.NORM_MINMAX)
    equalized_image = cv2.equalizeHist(normalized_image)
    
    # converting the images to CV_8U or CV_8UC3
    converted_image = cv2.convertScaleAbs(equalized_image)
    return converted_image

data_folder = 'C:/Users/soban/Desktop/CV/data'
folders = ['cats', 'dogs', 'horses']
X = []
y = []

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    for file_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, file_name)
        try:
            img = preprocess_image(img_path)
            hog_features = compute_hog_features(img)
            lbp_features = compute_lbp_features(img)
            combined_features = np.concatenate((hog_features, lbp_features))
            X.append(combined_features)
            y.append(folder)
        except Exception as e:
            print(f"Error processing image: {img_path}")
            print(e)

X = np.array(X)
y = np.array(y)

# Perform PCA for dimensionality reduction
pca = PCA(n_components=50)
X_pca = pca.fit_transform(X)

X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

svm_classifier = SVC(kernel='linear')

svm_classifier.fit(X_train, y_train)

y_pred = svm_classifier.predict(X_test)

# Evaluate performance
accuracy = accuracy_score(y_test, y_pred)
print(f"Accuracy of linear SVM: {accuracy}")

# %% [markdown]
# Experimenting with Different Kernel Functions

# %%
svm_linear = svm.SVC(kernel='linear')
svm_poly = svm.SVC(kernel='poly', degree=3)  # Polynomial kernel with degree 3
svm_rbf = svm.SVC(kernel='rbf')  # Radial basis function kernel

svm_linear.fit(X_train, y_train)
svm_poly.fit(X_train, y_train)
svm_rbf.fit(X_train, y_train)

y_pred_linear = svm_linear.predict(X_test)
y_pred_poly = svm_poly.predict(X_test)
y_pred_rbf = svm_rbf.predict(X_test)

accuracy_linear = accuracy_score(y_test, y_pred_linear)
accuracy_poly = accuracy_score(y_test, y_pred_poly)
accuracy_rbf = accuracy_score(y_test, y_pred_rbf)

print(f"Accuracy of linear SVM: {accuracy_linear}")
print(f"Accuracy of polynomial SVM: {accuracy_poly}")
print(f"Accuracy of RBF SVM: {accuracy_rbf}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 svm_linear = svm.SVC(kernel='linear')
#       2 svm_poly = svm.SVC(kernel='poly', degree=3)  # Polynomial kernel with degree 3
#       3 svm_rbf = svm.SVC(kernel='rbf')  # Radial basis function kernel
#
# NameError: name 'svm' is not defined

# %% [markdown]
# Impact of Kernel Functions on Classification Performance
#
# Linear Kernel: Works well for linearly separable data but may underperform on complex datasets with non-linear boundaries.
# Polynomial Kernel: Suitable for data with polynomial decision boundaries. The degree parameter controls the degree of the polynomial.
# RBF Kernel: Provides flexibility to capture complex decision boundaries. The gamma parameter controls the smoothness of the decision boundary, with smaller values leading to smoother boundaries.

# %% [markdown]
# # 5) Integration and Evaluation

# %%
import os
import cv2
import numpy as np
from random import choice
from skimage.feature import local_binary_pattern
from sklearn.decomposition import PCA
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis as LDA
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image as keras_image
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import preprocess_input

data_folder = 'C:/Users/soban/Desktop/CV/data'
folders = ['cats', 'dogs', 'horses']
target_count = 200

def augment_images(image_folder, target_count):
    images = os.listdir(image_folder)
    num_images = len(images)
    if num_images >= target_count:
        return  
    num_augmentations = target_count - num_images
    for i in range(num_augmentations):
        image_name = choice(images)
        image_path = os.path.join(image_folder, image_name)
        image = cv2.imread(image_path)
        if image is not None:
            angle = np.random.randint(-15, 15) # performing rotation with random angle within [-15, 15] degrees
            (h, w) = image.shape[:2]
            center = (w // 2, h // 2)
            M = cv2.getRotationMatrix2D(center, angle, 1.0)
            rotated_image = cv2.warpAffine(image, M, (w, h))
            cv2.imwrite(os.path.join(image_folder, f'augmented_{i}.jpg'), rotated_image)
            images.append(f'augmented_{i}.jpg')

def compute_hog_features(image):
    win_size = (64, 64)
    block_size = (16, 16)
    block_stride = (8, 8)
    cell_size = (8, 8)
    nbins = 9

    hog = cv2.HOGDescriptor(win_size, block_size, block_stride, cell_size, nbins)
    h = hog.compute(image)
    return h

def compute_lbp_features(image):
    radius = 3
    n_points = 8 * radius
    lbp = local_binary_pattern(image, n_points, radius, method='uniform')
    (hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    return hist

#using VGG16 as pre trained model
def extract_cnn_features(img_path, model):
    img = keras_image.load_img(img_path, target_size=(224, 224))
    img_data = keras_image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features.flatten()

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    augment_images(folder_path, target_count)
    print(f'Image augmentation complete for "{folder}". Total images: {len(os.listdir(folder_path))}')

# Feature extraction and dimensionality reduction

features_list, labels_list = [], []
label_map = {folder: idx for idx, folder in enumerate(folders)}

base_model = VGG16(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    label = label_map[folder]
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        image = cv2.imread(img_path)
        
        if image is not None:
            resized_image = cv2.resize(image, (64, 64))  # Resize for HOG and LBP
            gray_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
            hog_features = compute_hog_features(gray_image)
            lbp_features = compute_lbp_features(gray_image)
            cnn_features = extract_cnn_features(img_path, model)
            
            combined_features = np.hstack((hog_features.flatten(), lbp_features.flatten(), cnn_features))
            features_list.append(combined_features)
            labels_list.append(label)

X = np.array(features_list)
y = np.array(labels_list)

# applying PCA for dimensionality reduction
pca = PCA(n_components=50)
X_pca = pca.fit_transform(X)

# splitting data and training SVM
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

svm_classifier = svm.SVC(kernel='linear')
svm_classifier.fit(X_train, y_train)
y_pred = svm_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=folders)
print(f"Accuracy: {accuracy}")
print(report)
# Out:
# Image augmentation complete for "cats". Total images: 200
# Image augmentation complete for "dogs". Total images: 200
# Image augmentation complete for "horses". Total images: 200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 571ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# Accuracy: 0.875
#               precision    recall  f1-score   support
#
#         cats       0.81      0.88      0.84        43
#         dogs       0.87      0.75      0.81        36
#       horses       0.95      0.98      0.96        41
#
#     accuracy                           0.88       120
#    macro avg       0.88      0.87      0.87       120
# weighted avg       0.88      0.88      0.87       120

# %% [markdown]
# **Overall Accuracy**: The classifier achieved an accuracy of 0.875, meaning it correctly predicted the class for approximately 87.5% of the images.
#
# **Class-wise Performance**:
#
# - Cats: Precision, recall, and F1-score for the "cats" class are 0.81, 0.88, and 0.84 respectively. This indicates that out of all images predicted as "cats," 81% were actually cats. Moreover, it correctly identified 88% of the actual cat images, and the F1-score, which is the harmonic mean of precision and recall, is 0.84.
# - Dogs: Precision is 0.87, recall is 0.75, and F1-score is 0.81 for the "dogs" class. This means that 87% of the predicted dog images were actually dogs, and 75% of the actual dog images were correctly identified. The F1-score reflects the balance between precision and recall.
# - Horses: High precision, recall, and F1-score are observed for the "horses" class, with values of 0.95, 0.98, and 0.96 respectively. This indicates exceptional performance in identihorse imagesi
# mages.
#
# 1) Macro Average (0.87): This value represents the average of precision, recall, and F1-score across all classes without considering class imbalances. It gives an overall indication of the model's performance across all classes, treating each class equally.
#
# 2) Weighted Average (0.88): The weighted average considers the number of instances in each class, providing a more accurate representation of the model's overall performance across the dataset. It is similar to the macro average but gives more weight to classes with more instances.s o.erall.ns.

# %%
import os
import cv2
import numpy as np
from random import choice
from skimage.feature import local_binary_pattern
from sklearn.decomposition import PCA
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report
from tensorflow.keras.applications import VGG16
from tensorflow.keras.preprocessing import image as keras_image
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import preprocess_input
import pickle

data_folder = 'C:/Users/irsha/Downloads/CV/data/'
folders = ['cats', 'dogs', 'horses']
target_count = 200

def augment_images(image_folder, target_count):
    images = os.listdir(image_folder)
    num_images = len(images)
    if num_images >= target_count:
        return
    num_augmentations = target_count - num_images
    for i in range(num_augmentations):
        image_name = choice(images)
        image_path = os.path.join(image_folder, image_name)
        image = cv2.imread(image_path)
        if image is not None:
            angle = np.random.randint(-15, 15)  # performing rotation with random angle within [-15, 15] degrees
            (h, w) = image.shape[:2]
            center = (w // 2, h // 2)
            M = cv2.getRotationMatrix2D(center, angle, 1.0)
            rotated_image = cv2.warpAffine(image, M, (w, h))
            cv2.imwrite(os.path.join(image_folder, f'augmented_{i}.jpg'), rotated_image)
            images.append(f'augmented_{i}.jpg')

def compute_hog_features(image):
    win_size = (64, 64)
    block_size = (16, 16)
    block_stride = (8, 8)
    cell_size = (8, 8)
    nbins = 9

    hog = cv2.HOGDescriptor(win_size, block_size, block_stride, cell_size, nbins)
    h = hog.compute(image)
    return h

def compute_lbp_features(image):
    radius = 3
    n_points = 8 * radius
    lbp = local_binary_pattern(image, n_points, radius, method='uniform')
    (hist, _) = np.histogram(lbp.ravel(), bins=np.arange(0, n_points + 3), range=(0, n_points + 2))
    hist = hist.astype("float")
    hist /= (hist.sum() + 1e-6)
    return hist

# using VGG16 as pre-trained model
def extract_cnn_features(img_path, model):
    img = keras_image.load_img(img_path, target_size=(224, 224))
    img_data = keras_image.img_to_array(img)
    img_data = np.expand_dims(img_data, axis=0)
    img_data = preprocess_input(img_data)
    features = model.predict(img_data)
    return features.flatten()

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    augment_images(folder_path, target_count)
    print(f'Image augmentation complete for "{folder}". Total images: {len(os.listdir(folder_path))}')

# Feature extraction and dimensionality reduction
features_list=[] 
labels_list = []
label_map = {folder: idx for idx, folder in enumerate(folders)}

base_model = VGG16(weights='imagenet')
model = Model(inputs=base_model.input, outputs=base_model.get_layer('fc1').output)

for folder in folders:
    folder_path = os.path.join(data_folder, folder)
    label = label_map[folder]
    for img_name in os.listdir(folder_path):
        img_path = os.path.join(folder_path, img_name)
        image = cv2.imread(img_path)
        
        if image is not None:
            resized_image = cv2.resize(image, (64, 64))  # Resize for HOG and LBP
            gray_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
            hog_features = compute_hog_features(gray_image)
            lbp_features = compute_lbp_features(gray_image)
            cnn_features = extract_cnn_features(img_path, model)
            
            combined_features = np.hstack((hog_features.flatten(), lbp_features.flatten(), cnn_features))
            features_list.append(combined_features)
            labels_list.append(label)

X = np.array(features_list)
y = np.array(labels_list)

# Applying PCA for dimensionality reduction
pca = PCA(n_components=50)
X_pca = pca.fit_transform(X)

# Splitting data and training SVM
X_train, X_test, y_train, y_test = train_test_split(X_pca, y, test_size=0.2, random_state=42)

svm_classifier = svm.SVC(kernel='linear')
svm_classifier.fit(X_train, y_train)
y_pred = svm_classifier.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred, target_names=folders)
print(f"Accuracy: {accuracy}")
print(report)

with open('pca_transformer.pkl', 'wb') as pca_file:
    pickle.dump(pca, pca_file)

with open('svm_model.pkl', 'wb') as svm_file:
    pickle.dump(svm_classifier, svm_file)

def classify_image(img_path, model, pca, svm_classifier):
    image = cv2.imread(img_path)
    
    if image is not None:
        resized_image = cv2.resize(image, (64, 64))  # Resize for HOG and LBP
        gray_image = cv2.cvtColor(resized_image, cv2.COLOR_BGR2GRAY)
        hog_features = compute_hog_features(gray_image)
        lbp_features = compute_lbp_features(gray_image)
        cnn_features = extract_cnn_features(img_path, model)
        
        combined_features = np.hstack((hog_features.flatten(), lbp_features.flatten(), cnn_features))
        combined_features = combined_features.reshape(1, -1)
        
        # Apply PCA transformation
        features_pca = pca.transform(combined_features)
        
        # Classify with SVM
        prediction = svm_classifier.predict(features_pca)
        
        label_map_reverse = {v: k for k, v in label_map.items()}
        predicted_label = label_map_reverse[prediction[0]]
        return predicted_label
    else:
        return "Image not found or could not be read"

with open('pca_transformer.pkl', 'rb') as pca_file:
    pca = pickle.load(pca_file)

with open('svm_model.pkl', 'rb') as svm_file:
    svm_classifier = pickle.load(svm_file)
    
test_image_path = 'C:\\Users\\irsha\\Downloads\\CV\\data\\cats\\cat.95.jpg'
predicted_class = classify_image(test_image_path, model, pca, svm_classifier)
print(f'The test image is classified as: {predicted_class}')
# Out:
# Image augmentation complete for "cats". Total images: 200
# Image augmentation complete for "dogs". Total images: 200
# Image augmentation complete for "horses". Total images: 200
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 628ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 275ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 278ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 216ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 256ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 251ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 217ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 276ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 280ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 178ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 189ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 177ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 187ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 186ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 188ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 183ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 279ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 215ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 267ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 273ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 212ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 255ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 232ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 271ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 259ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 277ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 180ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 241ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 245ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 228ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 214ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 207ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 221ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 224ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 199ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 253ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 225ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 235ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 219ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 243ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 236ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 209ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 260ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 270ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 249ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 262ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 227ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 237ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 268ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 238ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 252ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 246ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 231ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 223ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 265ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 213ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 247ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 239ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 210ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 258ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 222ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 233ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 208ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 254ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 226ms/step
# Accuracy: 0.875
#               precision    recall  f1-score   support
#
#         cats       0.81      0.88      0.84        43
#         dogs       0.88      0.81      0.84        36
#       horses       0.95      0.93      0.94        41
#
#     accuracy                           0.88       120
#    macro avg       0.88      0.87      0.87       120
# weighted avg       0.88      0.88      0.88       120
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step
# The test image is classified as: horses
